# %%
#MODULOS DE SELENIUM
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from datetime import datetime

#MODULOS SECUNDARIOS
import pandas as pd
import numpy as np
import os
import time
import ssl
import sys
import traceback

#MODULO ALERTAS DESACTIVADAS
import warnings
warnings.filterwarnings('ignore')

#MODULO PROPIOS
from utils import limpiar_comentario

# %%
def PostFacebookScraper(VideoURL,Medio):
    
    driver = webdriver.Firefox()
    driver.get(VideoURL)

    try:
        time.sleep(1)
        # Espera a que el botón sea clickeable
        boton = driver.find_element(By.XPATH, "//div[@role='button' and contains(., 'Más pertinentes')]")
        boton.click()

        time.sleep(2)
        boton = driver.find_element(By.XPATH, "//span[contains(text(), 'Todos los comentarios')]")
        boton.click()
    except Exception as e:
        print("Ocurrió un error:", e)

    time.sleep(15)

    username         = "/html/body/div[1]/div/div[1]/div/div[3]/div/div/div[1]/div[1]/div/div/div/div/div/div/div[2]/div[2]/div/div/div/div/div/div/div/div/div/div/div/div/div[2]/div/div/div[4]/div/div/div[2]/div[3]/div["
    close_span_fan   = "]/div/div[1]/div[2]/div[1]/div[1]/div/div/span/span/a"
    close_span_nofan = "]/div/div[1]/div[2]/div[1]/div[1]/div/div/span"

    # comentario_nofan = "/html/body/div[1]/div/div[1]/div/div[3]/div/div/div[1]/div[1]/div/div/div/div/div/div/div[2]/div[2]/div/div/div/div/div/div/div/div/div/div/div/div/div[2]/div/div/div[4]/div/div/div[2]/div[3]/div[1 ]/div/div[1]/div[2]/div[1]/div[1]/div/div/div/span/div/div"
   
   
   
    # comentario_fan   = "/html/body/div[1]/div/div[1]/div/div[3]/div/div/div[1]/div[1]/div/div/div/div/div/div/div[2]/div[2]/div/div/div/div/div/div/div/div/div/div/div/div/div[2]/div/div/div[4]/div/div/div[2]/div[3]/div[2 ]/div/div[1]/div[2]/div[1]/div[1]/div/div/div[2]/span/div/div"
                    #  = "/html/body/div[1]/div/div[1]/div/div[3]/div/div/div[1]/div[1]/div/div/div/div/div/div/div[2]/div[2]/div/div/div/div/div/div/div/div/div/div/div/div/div[2]/div/div/div[4]/div/div/div[2]/div[3]/div[4]/div/div[1]/div[2]/div[1]/div[1]/div/div/div[2]/span/div/div"

                    ## = "/html/body/div[1]/div/div[1]/div/div[3]/div/div/div[1]/div[1]/div/div/div/div/div/div/div[2]/div[2]/div/div/div/div/div/div/div/div/div/div/div/div/div[2]/div/div/div[4]/div/div/div[2]/div[3]/div[1 ]/div/div[1]/div[2]/div[1]/div[1]/div/div/div/span/div/div" 
                    # =  "/html/body/div[1]/div/div[1]/div/div[3]/div/div/div[1]/div[1]/div/div/div/div/div/div/div[2]/div[2]/div/div/div/div/div/div/div/div/div/div/div/div/div[2]/div/div/div[4]/div/div/div[2]/div[3]/div[3 ]/div/div[1]/div[2]/div[1]/div[1]/div/div/div[2]/span/div/div"
                    
                    
                     # = "/html/body/div[1]/div/div[1]/div/div[3]/div/div/div[1]/div[1]/div/div/div/div/div/div/div[2]/div[2]/div/div/div/div/div/div/div/div/div/div/div/div/div[2]/div/div/div[4]/div/div/div[2]/div[3]/div[4 ]/div/div[1]/div[2]/div[1]/div[1]/div/div/div/span/div/div"
                    ## = "/html/body/div[1]/div/div[1]/div/div[3]/div/div/div[1]/div[1]/div/div/div/div/div/div/div[2]/div[2]/div/div/div/div/div/div/div/div/div/div/div/div/div[2]/div/div/div[4]/div/div/div[2]/div[3]/div[4 ]/div/div[1]/div[2]/div[1]/div[1]/div/div/div/span/div"
                    
                    #  = "/html/body/div[1]/div/div[1]/div/div[3]/div/div/div[1]/div[1]/div/div/div/div/div/div/div[2]/div[2]/div/div/div/div/div/div/div/div/div/div/div/div/div[2]/div/div/div[4]/div/div/div[2]/div[3]/div[3 ]/div/div[1]/div[2]/div[1]/div[1]/div/div/div[2]/span/div/div"
                                        
    comentario_nofan = "/html/body/div[1]/div/div[1]/div/div[3]/div/div/div[1]/div[1]/div/div/div/div/div/div/div[2]/div[2]/div/div/div/div/div/div/div/div/div/div/div/div/div[2]/div/div/div[4]/div/div/div[2]/div[3]/div["
    comentario_fan   = "/html/body/div[1]/div/div[1]/div/div[3]/div/div/div[1]/div[1]/div/div/div/div/div/div/div[2]/div[2]/div/div/div/div/div/div/div/div/div/div/div/div/div[2]/div/div/div[4]/div/div/div[2]/div[3]/div["
                       

    close_span_comentario_nofan     = "]/div/div[1]/div[2]/div[1]/div[1]/div/div/div/span/div/div"
    close_span_comentario_fan       = "]/div/div[1]/div[2]/div[1]/div[1]/div/div/div[2]/span/div/div"

    Centinela         = True
    NumberUserInterno = 1

    PostFBCommentBase = pd.DataFrame(columns=["Username","Comment"]) 

    while Centinela == True: 

            try:

                username_thread = driver.find_element(by=By.XPATH,value= f'{username}{NumberUserInterno}{close_span_fan}').text
                try:
                    comentario      = driver.find_element(by=By.XPATH,value= f'{comentario_fan}{NumberUserInterno}{close_span_comentario_fan}').text
                except:
                    pass
                    
                TemporalDataRow    = pd.DataFrame([{ "Username": username_thread,"Level": 1,"Comment": comentario}])
                PostFBCommentBase  = pd.concat([PostFBCommentBase,TemporalDataRow])     
                print(f"Comentario {NumberUserInterno}:{username_thread}_{comentario}")
                time.sleep(0.15)
                NumberUserInterno  = NumberUserInterno + 1
            
            except:
                
            
                try:
                    username_thread = driver.find_element(by=By.XPATH,value= f'{username}{NumberUserInterno}{close_span_nofan}').text
                    try:
                        comentario      = driver.find_element(by=By.XPATH,value= f'{comentario_nofan}{NumberUserInterno}{close_span_comentario_nofan}').text
                    except:
                        pass
                    
                    
                    print(f"Comentario {NumberUserInterno}:{username_thread}_{comentario}")
                    time.sleep(0.15)

                    TemporalDataRow    = pd.DataFrame([{ "Username": username_thread,"Level": 1,"Comment": comentario}])
                    PostFBCommentBase  = pd.concat([PostFBCommentBase,TemporalDataRow])    

                    NumberUserInterno  = NumberUserInterno + 1

                except Exception as e:
                    try:
                        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
                        filename = f'data_{Medio}_{timestamp}.xlsx'
                        PostFBCommentBase.to_excel(filename,index=False)
                        print(e)
                        print("POST TERMINADO")
                        # driver.quit()
                        break
                    except:
                        break

# %%
url = "https://web.facebook.com/CanalRTU/posts/pfbid02UrXMcozkctzNrUwG3N8mseMJtU6KUBscz23fmY2B9LKxodXtvrNcaZhvgV4jknvUl#"
PostFacebookScraper(VideoURL=url,Medio="Ecuavisa")

# %%
textos_comentarios =  ['吉多帕布\nRTU=RC5\n1 h',
 'Marielita Plaza\n2 h',
 'Victor Leon\nEstas rratas no sirven para nada\n59 min']

limpios            = [limpiar_comentario(texto) for texto in textos_comentarios]
limpios
