# %%
seccion_comments = 
/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div/div[


# nombre_titulo del post/<class>
/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div/div[ 1 ]/div/div[2]/div/span/div/div/span[1]/div/a
# titulo del post/<span/class>
/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div/div[ 1 ]/div/div[2]/div/span/div/span

# nombre_primer comentario/<class>
/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div/div[ 2 ]/div/div[2]/div[1]/div[1]/div/div[1]/span[1]/span/div/a
/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div/div[ 2 ]/div/div[2]/div[1]/div[1]/div/div[1]/span[1]/span/div/a

/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div/div[2]/div/div[2]/div[1]/div[1]/div/div[1]/span[1]/span/div/a

# primer comentario/<span/class>
/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div/div[ 2 ]/div/div[2]/div[1]/div[1]/div/div[2]/span

'''-----click Ver Respuesta-------'''
## ver_respuesta_01
/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div/div[ 3 ]/div/div/span
'''-----respuestas 01----------------'''
### nombre_primera_respuesta
/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div/div[ 3 ]/ul/div/div/div[2]/div[1]/div[1]/div/div[1]/span[1]/span/div/a
#### comentario_primera_respuesta/span<class>                                                                                           
/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div/div[ 3 ]/ul/div/div/div[2]/div[1]/div[1]/div/div[2]/span


# nombre_segundo comentario/<class>
/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div/div[ 4 ]/div/div[2]/div[1]/div[1]/div/div[1]/span[1]/span/div/a
# segundo comentario/<span/class>
/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div/div[ 4 ]/div/div[2]/div[1]/div[1]/div/div[2]/span
## ver_respuesta_02


# nombre_tercer comentario/
/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div/div[ 5 ]/div/div[2]/div[1]/div[1]/div/div[1]/span[1]/span/div/a
## ver_respuesta_02
/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div/div[ 6 ]/div/div/span
'''-----respuestas 01----------------'''
### nombre_primera_respuesta
/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div/div[ 6 ]/ul/div/div/div[2]/div[1]/div[1]/div/div[1]/span[1]/span/div/a
#### comentario_primera_respuesta/span<class>
/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div/div[ 6 ]/ul/div/div/div[2]/div[1]/div[1]/div/div[2]/span



# nombre_cuarto comentario/
/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div/div[ 7 ]/div/div[2]/div[1]/div[1]/div/div[1]/span[1]/span/div/a
## ver_respuesta_03
/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div/div[ 8 ]/div/div/span
'''-----respuestas 04----------------'''
### nombre_primera_respuesta/<a/class>
/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div/div[ 8 ]/ul/div[ 1 ]/div/div[2]/div[1]/div[1]/div/div[1]/span[1]/span/div/a
#### comentario_primera_respuesta/span<class>
/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div/div[ 8 ]/ul/div[ 1 ]/div/div[2]/div[1]/div[1]/div/div[2]/span


### nombre_segunda_respuesta
/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div/div[ 8 ]/ul/div[ 2 ]/div/div[2]/div[1]/div[1]/div/div[1]/span[1]/span/div/a
#### comentario_segunda_respuesta/span<class>
/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div/div[ 8 ]/ul/div[ 2 ]/div/div[2]/div[1]/div[1]/div/div[2]/span

# %%
'''CLICK

Primer VER RESPUESTA'''

ver_respuesta = driver.find_element(By.XPATH,value = '/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div/div[3]/div/div/span')
ver_respuesta.click()
print('click realizado')


Ver respuestas
/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[2]/div[ 1 ]/div[2]/div/div/span
/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[2]/div[ 2 ]/div[2]/div/div/span

# %%
/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[ 1 ]/div/div[2]/div/span/div/div/span[1]/div/a/div/div/span
/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[ 1 ]/div/div[2]/div/span/div/div/span[1]/div/a


/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[ 2 ]/div[ 1 ]/div[1]/div/div[2]/div[1]/div[1]/div/div[1]/span[1]/span/div/a/div/div/span
/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[ 2 ]/div[ 1 ]/div[1]/div/div[2]/div[1]/div[1]/div/div[2]/span

/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[ 2 ]/div[ 2 ]/div[1]/div/div[2]/div[1]/div[1]/div/div[1]/span[1]/span/div/a/div/div/span
/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[ 2 ]/div[ 2 ]/div[1]/div/div[2]/div[1]/div[1]/div/div[2]/span



/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[ 2 ]/div[ 3 ]/div/div/div[2]/div[1]/div[1]/div/div[1]/span[1]/span/div/a/div/div/span

/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[ 2 ]/div[ 4 ]/div[1]/div/div[2]/div[1]/div[1]/div/div[1]/span[1]/span/div/a/div/div/span

/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[ 2 ]/div[ 5 ]/div[1]/div/div[2]/div[1]/div[1]/div/div[1]/span[1]/span/div/a/div/div/span

# %%
/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[2]/div[ 1 ]/div[2]/div/div/span

/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[2]/div[ 1 ]/div[2]/ul/div[ 1 ]/div/div[2]/div[1]/div[1]/div/div[1]/span[1]/span/div/a/div/div/span
/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[2]/div[ 1 ]/div[2]/ul/div[ 2 ]/div/div[2]/div[1]/div[1]/div/div[1]/span[1]/span/div/a/div/div/span
