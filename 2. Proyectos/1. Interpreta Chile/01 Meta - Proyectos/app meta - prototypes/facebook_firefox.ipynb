# %%
#MODULOS DE SELENIUM
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains

#MODULOS SECUNDARIOS
import pandas as pd
import numpy as np
import os
import time
import ssl
import sys
import traceback

#MODULO ALERTAS DESACTIVADAS
import warnings
warnings.filterwarnings('ignore')

#MODULO PROPIOS
from functions.funciones_primarias import validacion_instagram
from functions.funciones_secundarias import scroll_down_times, barra_carga
from functions.driver_manager_facebook import ManagerDriverFacebook

# %%
Username  = "datos_barometro@hotmail.com"
PassWord  = "Libertad5%"

# 308940666579152
 
ManagerDriverFacebook(
    
    facebookURL = "https://www.facebook.com/",
    username    = "datos_baroemetro@hotmail.com",
    password    = "Libertad5%",
    GroupURL    = "https://www.facebook.com/groups/308940666579152/?sorting_setting=RECENT_ACTIVITY", #recent_activity (sorting) 
    ProfileURL  = None
    
    )
# Out:
# 12345678910 ---- 100% PAGE CORRECT LOADED
# 12345678910 ---- 100% ACCESS SUCCESFULL
# 12345678910 ---- 100% PROFILE ACCESS GRANTED
# Scroll 1/3: desplazado a 10198
# Scroll 2/3: desplazado a 14929
# Scroll 3/3: desplazado a 18947
# Scroll 1/1: desplazado a 22802
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# Aquí tienes una descripción lista para publicar en redes sociales, dirigida a la audiencia venezolana en Colombia:
# ¡Atención venezolanos en Colombia!
# Si eres representante legal o custodio de un niño o adolescente venezolano con Permiso por Protección Temporal (PPT), ¡tenemos buenas noticias para ti! El gobierno colombiano ha creado el PEP-TUTOR, un permiso especial que te permitirá regularizar tu situación migratoria y acceder a todos los derechos que mereces: trabajo, salud, educación y mucho más.
#  ¿Qué es el PEP-TUTOR?
# Es un documento que te ayuda a ti y a tu familia a vivir con estabilidad en Colombia, mientras proteges a los menores a tu cargo. Además, es el primer paso hacia una residencia legal en el país.
#  Requisitos básicos:
# Ser representante legal o custodio de un menor con PPT.
# Estar en Colombia antes del 31 de diciembre de 2023.
# No tener antecedentes penales.
#  Beneficios:
# Trabaja de manera legal.
# Accede a servicios de salud y educación.
# Estabilidad migratoria para ti y los tuyos.
# Este es el momento de asegurar el bienestar de tu familia. ¡No pierdas esta oportunidad!
# 12345 ---- 100% publication : 2 complete
# Me gusta: 3 personas
# Me encanta: 1 persona
# 12345 ---- 100% publication : 2 complete
# 123 ---- 100%
#  Hola me puedes ayudar
# 123 ---- 100%
#  Ya se puede acceder a el pep-tutor
# Scroll 1/1: desplazado a 26562
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# Jornada de Servicio en el Porvenir - Itagüí:
#  Con el apoyo de grandes organizaciones como @cfacooperativa  @senacomunica @aavancecard  @oimcolombia  @enterritorioco @corporacionsomossentirhumano  y la participación especial de @corpoayudahumanitaria  logramos impactar a las comunidades más necesitadas.
# Durante este evento, se ofrecieron servicios clave como:
#  Soluciones financieras
#  Identificación de casos vulnerables
#  Apoyo jurídico
#  Ofertas de empleo
#  Afiliación al sistema de salud
# COLVENZ continúa llevando estos servicios esenciales a zonas donde el apoyo a la población migrante, colombianos retornados y la comunidad de acogida es limitado.
#  #UnidosPorLaComunidad #ServiciosParaTodos #JornadaDeServicio
# 12345 ---- 100% publication : 3 complete
# Me gusta: 2 personas
# 12345 ---- 100% publication : 3 complete
# Scroll 1/1: desplazado a 29998
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
#  ¡Colvenz, en la Gran Protesta Mundial!
# Este sábado 28 de septiembre a las 4:30 PM nos encontraremos en el Parque de las Luces para caminar juntos bajo nuestra Gigantesca Bandera de Venezuela. Este acto simboliza la unión y la esperanza de todos los venezolanos que luchamos por la libertad de nuestro país.
#  Lugar: Parque de las Luces
#  Hora: 4:30 PM
# Demostremos que la causa que nos une es más fuerte que las distancias. ¡Tu presencia cuenta!
# #VenezuelaLibre #ProtestaMundial #Colvenz #LuchaPorLaLibertad #UnidosPorVenezuela #EsperanzaVenezolana
# 12345 ---- 100% publication : 4 complete
# Me gusta: 3 personas
# 12345 ---- 100% publication : 4 complete
# Scroll 1/1: desplazado a 32367
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# ¡Gran éxito en nuestra jornada de servicio en el corregimiento!
# Con la participación de 120 personas, se brindaron diversos servicios esenciales y orientación para mejorar su bienestar y acceder a derechos importantes. Agradecemos a todos los que hicieron posible este día.
#  Aseguramiento EPS: 12 personas atendidas
#  Pre-registro RuR Cancillería (Colvenz): 4 personas
#  Revisión de Orden de Laboratorios (ADRA): 18 personas
#  Emprendimiento y Finanzas (CFA): 20 personas asesoradas
#  Educación y Formación (OIM): 15 personas orientadas
#  Caracterización de Vulnerabilidad (World Vision): 58 familias atendidas y 20 pre-registros
#  Registro PPT para Menores (Anauco OIM PRO): 10 personas atendidas
#  Orientación y Acceso a Derechos (Heartland Alliance): 45 personas atendidas
#  Orientación en Derechos, Sisben y Carta Vencida (JAL): 32 personas orientadas
# Un día lleno de esperanza y apoyo comunitario. ¡Seguimos construyendo juntos!
#  #JornadaDeServicio #Comunidad #ApoyoSocial #DerechosHumanos #Corregimiento #EsperanzaParaTodos
# 12345 ---- 100% publication : 5 complete
# 123 ---- 100% publication : 5 complete
# 123 ---- 100%
#  Cunado vienen a Barranquilla
# Scroll 1/1: desplazado a 37647
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
#  ¡Atención comunidad migrante!
# ¿Sabías que tener pensamiento crítico y gestionar correctamente tu información en entornos digitales es clave para protegerte en la red?
# Te invitamos a participar en una sesión especial de la mano de Colvenz, META e Impacto TIC, donde hablaremos sobre:
#  La importancia del pensamiento crítico para la población migrante
#  Cómo detectar desinformación
#  Identificación de señales de alarma en contenidos de internet
#  Protección de tu información en el entorno digital
# ¡No te lo pierdas!
#   Fecha: Martes 17 de septiembre
#  Hora: 5:00 p.m. a 7:00 p.m.
#  Inscríbete aquí: https://bit.ly/4efY2oB (link en bio si estas en #Instagram)
# .
# #CiudadaníaDigital #MigrantesEnColombia #PensamientoCrítico #ProtecciónDeDatos #Colvenz #Meta #ImpactoTIC
# 12345 ---- 100% publication : 6 complete
# 123 ---- 100% publication : 6 complete
# Scroll 1/1: desplazado a 41835
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# ATENCIÓN COMUNIDAD: ERES MIGRANTE REGULAR o COLOMBIANO RETORNADO? Inscríbete en la Mesa Nacional de la Sociedad Civil para las Migraciones y sé parte fundamental de la construcción de la política migratoria colombiana.
# La Mesa te ofrece la oportunidad de participar en la construcción de las políticas públicas que impactan directamente a la colombianidad en el exterior, a l@s que retornan y a migrantes regulares en Colombia.
# Tu voz es crucial para fortalecer los vínculos entre el Estado y la ciudadanía en el desarrollo de una política migratoria inclusiva y efectiva.
# ¡Participa y contribuye a la construcción de la política migratoria de nuestro país!
# Para facilitar su registro, le recomendamos tener a mano el documento que lo acredita como migrante regular en Colombia o el certificado único de retorno (RUR), que lo acredita como retornado, en formato PDF, JPG, JPEG, o PNG con un tamaño máximo de 5MB. Los documentos pueden incluir: visa de migrante (tipo M), visa de residente (tipo R), Permiso por Protección Temporal (PPT) o salvoconducto por refugio (SC-2) vigentes en el caso de los migrantes. Puede realizar el registro de manera ágil y sencilla a través del siguiente enlace (Link en bio de instagram):
# https://inscripcionmnscm.cancilleria.gov.co/
# 12345 ---- 100% publication : 7 complete
# 123 ---- 100% publication : 7 complete
# Scroll 1/1: desplazado a 45278
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# ATENCIÓN COMUNIDAD: ERES MIGRANTE REGULAR o COLOMBIANO RETORNADO? Inscríbete en la Mesa Nacional de la Sociedad Civil para las Migraciones y sé parte fundamental de la construcción de la política migratoria colombiana.
# La Mesa te ofrece la oportunidad de participar en la construcción de las políticas públicas que impactan directamente a la colombianidad en el exterior, a l@s que retornan y a migrantes regulares en Colombia.
# Tu voz es crucial para fortalecer los vínculos entre el Estado y la ciudadanía en el desarrollo de una política migratoria inclusiva y efectiva.
# ¡Participa y contribuye a la construcción de la política migratoria de nuestro país!
# Para facilitar su registro, le recomendamos tener a mano el documento que lo acredita como migrante regular en Colombia o el certificado único de retorno (RUR), que lo acredita como retornado, en formato PDF, JPG, JPEG, o PNG con un tamaño máximo de 5MB. Los documentos pueden incluir: visa de migrante (tipo M), visa de residente (tipo R), Permiso por Protección Temporal (PPT) o salvoconducto por refugio (SC-2) vigentes en el caso de los migrantes. Puede realizar el registro de manera ágil y sencilla a través del siguiente enlace (Link en bio de instagram):
# https://inscripcionmnscm.cancilleria.gov.co/
# 12345 ---- 100% publication : 8 complete
# 123 ---- 100% publication : 8 complete
# Scroll 1/1: desplazado a 47154
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# ATENCIÓN COMUNIDAD: ERES MIGRANTE REGULAR o COLOMBIANO RETORNADO? Inscríbete en la Mesa Nacional de la Sociedad Civil para las Migraciones y sé parte fundamental de la construcción de la política migratoria colombiana.
# La Mesa te ofrece la oportunidad de participar en la construcción de las políticas públicas que impactan directamente a la colombianidad en el exterior, a l@s que retornan y a migrantes regulares en Colombia.
# Tu voz es crucial para fortalecer los vínculos entre el Estado y la ciudadanía en el desarrollo de una política migratoria inclusiva y efectiva.
# ¡Participa y contribuye a la construcción de la política migratoria de nuestro país!
# Para facilitar su registro, le recomendamos tener a mano el documento que lo acredita como migrante regular en Colombia o el certificado único de retorno (RUR), que lo acredita como retornado, en formato PDF, JPG, JPEG, o PNG con un tamaño máximo de 5MB. Los documentos pueden incluir: visa de migrante (tipo M), visa de residente (tipo R), Permiso por Protección Temporal (PPT) o salvoconducto por refugio (SC-2) vigentes en el caso de los migrantes. Puede realizar el registro de manera ágil y sencilla a través del siguiente enlace (Link en bio de instagram):
# https://inscripcionmnscm.cancilleria.gov.co/
# 12345 ---- 100% publication : 9 complete
# 123 ---- 100% publication : 9 complete
# Scroll 1/1: desplazado a 50531
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# ¡Continuamos trabajando en equipo para que nuestras acciones sean sean sostenibles en el tiempo!��#SantaMarta fue el punto de encuentro donde 20 organizaciones comunitarias del país unimos fuerzas e intercambiamos experiencias, conocimientos y buenas prácticas sobre la integración e inclusión de la población migrante y colombiana al #SistemaDeSalud.��En esta galería de fotos te mostramos los momentos destacados de este evento, que contó con el apoyo del Programa #ComunidadesSaludables de @USAIDColombia - @LHSSProject, @MinSaludCol y @secretariadesaludsmr.
# 12345 ---- 100% publication : 10 complete
# 123 ---- 100% publication : 10 complete
# Scroll 1/1: desplazado a 56529
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# ATENCIÓN COMUNIDAD:
# Este sábado 17 de agosto, únete a la Gran Protesta Mundial por la Verdad de Venezuela
#  Más de 115 ciudades ya tienen hora y lugar de encuentro para exigir que se respeten los resultados del 28J y ratificar que #GanóVzla.
# Estaremos en Medellín en el Parque de las Luces.
# #JuntosEl17 alzaremos la voz por nuestro país.
# 12345 ---- 100% publication : 11 complete
# Me gusta: 2 personas
# Me encanta: 2 personas
# 12345 ---- 100% publication : 11 complete
# Scroll 1/1: desplazado a 59737
# 1234 ---- 100%  contenent has no text, is photo,video or post withoout text
# Me gusta: 6 personas
# 12345 ---- 100% publication : 13 complete
# Scroll 1/1: desplazado a 62281
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# ¡Atención, comunidad venezolana en Colombia!
# Estamos a solo días de un evento crucial para nuestro país. COLVENZ te acompaña en las elecciones presidenciales de Venezuela 2024 este 28 de julio.
#  Fecha: 28 de julio de 2024
#  Lugares de concentración:
#  Medellín: Plaza frente al Restaurant Palma Verde, Transversal 39B # 79A-39, 7 AM
# Bogotá: Parque Distrital Alfonso Lopez, 8:30 AM
#  Bucaramanga: Parque San Pio, CRA 33 CON CL 45 CABECERA, 2 PM
# Cali: Boulevard Rio Cali, 10 AM
#  Barranquilla: Parque Tomas Suri Salcedo, CL 70 CON CRA 47 Norte, 8 AM
#  Santa Marta: Plaza Bolivar, 3 PM
#  Pereira: Parque El Lago, 8 AM
#  Cúcuta: Frente al Terminal de Copetran, 4 PM
#  Cartagena: Plazoleta del Banco Agrario, 8 AM
# Únete a nosotros en estos puntos de concentración pacífica convocados por organizaciones oficiales. Estamos aquí para brindarte información, orientación y apoyo en este evento tan importante para Venezuela.
# Recuerda, ¡el poder está en tus manos!
# #Venezuela2024 #EleccionesVenezuela #COLVENZ #VenezolanosEnColombia #Democracia #TuVotoCuenta
# 12345 ---- 100% publication : 14 complete
# Me gusta: 1 persona
# 12345 ---- 100% publication : 14 complete
# Scroll 1/1: desplazado a 66701
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# ATENCIÓN COMUNIDAD: EN BOGOTÁ
# Es un placer para la Organización Internacional para las Migraciones (OIM) la Fundación Konrad Adenauer (KAS) y la Fundación Ideas para la Paz (FIP)  invitarlo/a  a participar de la presentación del estudio de impacto económico de la migración venezolana en Colombia. Dicho estudio, es parte de un proyecto regional que se viene desarrollando en diferentes países de Latinoamérica y el Caribe con el objetivo de visibilizar empíricamente la importancia de la migración como un motor de desarrollo en los países de acogida.
# Gracias al trabajo de la consultora Equilibrium y el apoyo de la Cámara de Empresarios y Ejecutivos Venezolanos en el Exterior (CAVEX), Colombia es el octavo país donde presentamos este estudio.
# 22 de abril
# @camaracomerbog sede Chapinero (calle 67# 8 – 32/34).
# Link de inscripción en nuestra BIO.
# Invitan: @ideaspaz @oimcolombia #EquilibriumSDC y la #KASColombia.
# @coalicionve
# @kas_colombia
# @cavexoficial
# @oimcolombia
# .
# .
# #CoalicionVE
# #CAVEX
# #ChangeMakers #somoscolvenz
# #somoscolonia
# #SomosLaClave
# #Venezolanosenelexterior
# #migracionvenezolana
# #venezolanosenelextranjero
# #venezolanosporelmundo
# 12345 ---- 100% publication : 15 complete
# Me gusta: 3 personas
# Me encanta: 1 persona
# 12345 ---- 100% publication : 15 complete
# Scroll 1/1: desplazado a 69303
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# ATENCIÓN #VenezolanosenelExterior
# Hasta el 16 de abril hay chance de actualizar datos o registrase en el Registro Electoral para los venezolanos en Medellín.
# Según pudimos conocer, los requisitos son:
# 1. Haber cumplido los 18 años de edad.
# 2. Cédula Venezolana (vigente o no).
# 3. Pasaporte (vigente o constancia de renovación).
# 4. Constancia de residencia.
# 5. Documento que demuestre su residencia legal permanente en el extranjero.
# 6. NO cuentan como constancia de residencia legal para inscripción Permiso de Protección Temporal (PPT) O PEP . DEBE SER cédula de extranjería o la visa de residente.
# Recuerda que si cumples con todos los requisitos y quieres participar en el próximo proceso electoral, puedes dirigirte al Consulado de Venezuela en Medellín en la calle 42 #79-06, barrio Laureles.
# Horarios de 8:30 AM a 12:30 P
# @coalicionve
# @mesumocolombia
# .
# #migracionvenezolana
# #venezolanosenelextranjero
# #venezolanosporelmundo
# #venezolanosporelmundo
# 12345 ---- 100% publication : 16 complete
# Me enfada: 2 personas
# Me asombra: 1 persona
# 12345 ---- 100% publication : 16 complete
# Scroll 1/1: desplazado a 73325
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# ATENCIÓN #VenezolanosenelExterior
# Hasta el 16 de abril hay chance de actualizar datos o registrase en el Registro Electoral para los venezolanos en Medellín.
# Según pudimos conocer, los requisitos son:
# 1. Haber cumplido los 18 años de edad.
# 2. Cédula Venezolana (vigente o no).
# 3. Pasaporte (vigente o constancia de renovación).
# 4. Constancia de residencia.
# 5. Documento que demuestre su residencia legal permanente en el extranjero.
# 6. NO cuentan como constancia de residencia legal para inscripción Permiso de Protección Temporal (PPT) O PEP . DEBE SER cédula de extranjería o la visa de residente.
# Recuerda que si cumples con todos los requisitos y quieres participar en el próximo proceso electoral, puedes dirigirte al Consulado de Venezuela en Medellín en la calle 42 #79-06, barrio Laureles.
# Horarios de 8:30 AM a 12:30 PM / 2:30 PM a 5:00 PM
# .
# #migracionvenezolana
# #venezolanosenelextranjero
# #venezolanosporelmundo
# 12345 ---- 100% publication : 17 complete
# Me enfada: 1 persona
# 12345 ---- 100% publication : 17 complete
# Scroll 1/1: desplazado a 77347
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# Mesa Ampliada de Salud - Medellin. Desde la Secretaría de Salud de Medellín tienen un fuerte compromiso por una salud inclusiva y equitativa. Por esto, con el apoyo del Programa Comunidades Saludables de USAID los estamos invitando a la Mesa Ampliada de Salud con enfoque migratorio, un espacio en que juntos pensaremos y analizaremos las principales necesidades/problemáticas en salud y haremos propuestas para aportar a las soluciones desde nuestras capacidades individuales y comunitarias. Esta información hará parte de los instrumentos de planeación de la salud en la ciudad.
# .
# .
# .
# Gracias a @usaidcolombia a la @gobantioquia  y a nuestros aliados, todos los actores, comunidades e instituciones, por el apoyo y el impulso en estas actividades, como siempre seguimos avanzando por la integración social.
# .
# @coalicionve
# .
# #somoscolvenz
# #somoscolonia
# #SomosLaClave
# #Venezolanosenelexterior
# #migracionvenezolana
# #venezolanosenelextranjero
# #venezolanosporelmundo
# 12345 ---- 100% publication : 18 complete
# Me gusta: 1 persona
# Me encanta: 1 persona
# 12345 ---- 100% publication : 18 complete
# Scroll 1/1: desplazado a 80386
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# Actividades COLVENZ: En Marzo, se llevó a cabo la, Primera Sesión Ordinaria de la Comisión para la Gestión de la Gobernanza Migratoria en Antioquia. Con la participación de la Cooperación internacional, Gobernación de Antioquia, Migración  Colombia, Cancillería de Colombia y las Organizaciones de Base Comunitarias.
# .
# En el evento, se abordaron las necesidades de la población migrante, especialmente aquellos en tránsito, donde se han identificado hasta 110 nacionalidades que cruzan el Darién. Se discutió sobre la población con vocación de residente, con el objetivo de desarrollar políticas públicas más adaptadas a las realidades de la población migrante y los colombianos retornados. COLVENZ sigue participando en los espacios para la construcción de la integración socio-económica y cultural en los próximos 4 años en Antioquia.
# .
# .
# .
# Gracias a la @gobantioquia y a nuestros aliados, todos los actores, comunidades e instituciones, por el apoyo y el impulso en estas actividades, como siempre seguimos avanzando por la integración en este país que nos brindan muchas oportunidades de desarrollo.
# .
# @cancilleriacol
# @migracioncol
# @coalicionve
# .
# .
# .
# #somoscolvenz
# #somoscolonia
# #SomosLaClave
# #Venezolanosenelexterior
# #migracionvenezolana
# #venezolanosenelextranjero
# #venezolanosporelmundo
# 12345 ---- 100% publication : 19 complete
# Me gusta: 3 personas
# Me encanta: 2 personas
# 12345 ---- 100% publication : 19 complete
# Scroll 1/1: desplazado a 86822
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# ¡Hoy celebramos el día de la mujer, un día para honrar la fortaleza, la perseverancia y la valentía de todas las mujeres alrededor del mundo! En este día especial, desde COLVENZ le dedicamos estas palabras especialmente a las mujeres migrantes que, con su coraje y determinación, están trabajando incansablemente para mejorar la situación de los desplazados.
# Su lucha es un faro de esperanza en medio de la adversidad. Su dedicación y esfuerzo son ejemplos vivientes de lo que significa tener el poder de cambiar el mundo. A pesar de los desafíos y obstáculos, siguen adelante con una determinación inquebrantable, recordándonos a todos que no hay límites para lo que una mujer puede lograr.
# En este día, les enviamos todo nuestro apoyo y gratitud. Su contribución no solo enriquece nuestras comunidades, sino que también inspira a las generaciones futuras a perseguir sus sueños y a creer en su propio potencial.
# Recuerden siempre que tienen el derecho innegable a vivir una vida llena de libertad y dignidad. Su voz merece ser escuchada, sus sueños merecen ser realizados y su lugar en el mundo merece ser respetado.
# ¡Sigamos adelante juntas, construyendo un mundo más justo y lleno de oportunidades para todas las mujeres y para todos, sin importar su origen o situación!
# MUJER: Hoy celebramos tu coraje, tu fuerza y tu inquebrantable espíritu.
# ¡Feliz día de la mujer!
# 12345 ---- 100% publication : 20 complete
# Me gusta: 2 personas
# 12345 ---- 100% publication : 20 complete
# Scroll 1/1: desplazado a 89180
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# Actividades en URABÁ: en el municipio de Apartadó Antioquia subregión de Urabá se realizó la 3era jornada social dirigida a la población migrantes de paso, logrando beneficiar 200 migrantes de paso con:
# - Cortes de cabellos
# - Perfilamiento de cejas
# - Peinados para niñas
# - Alimentos, fórmulas de leche para niños recién nacidos
# - Ropa y calzados
# - Medicinas para casos preventivos
# - Atención y gestión de casos especiales
# - Componente psicosocial y espiritual.
# .
# Gracias a la Iglesia Ámbito Interno, al Concejal de Apartadó Deibis Palacios a Sura EPS, a nuestra representante en gestión comunitaria Marlyn Luque y muy
#  especial agradecimiento al Gremio de Barberos y Estilistas de la Subregión, Fundación Manos Hacia la Obra, Psicología DLux y a la Panadería Kirié, por todo el  apoyo e impulso en estas actividades, como siempre seguimos avanzando por la integración en este país que nos brindan muchas oportunidades de desarrollo.
# .
# .
# .
# #somoscolvenz
# #somoscolonia
# #SomosLaClave
# #Venezolanosenelexterior
# #migracionvenezolana
# #venezolanosenelextranjero
# #venezolanosporelmundo
# 12345 ---- 100% publication : 21 complete
# Me gusta: 2 personas
# 12345 ---- 100% publication : 21 complete
# Scroll 1/1: desplazado a 93854
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# Más del  apoyo por parte de @corpopcionlegal a las #OBCs, Proyecto Intégrate con el plan de desarrollo distrital. Con la representación de algunas de las OBCs en Medellín, brindando acompañamiento técnico. Lo anterior, con el ánimo de facilitar la definición de propuestas para incidir en la construcción del Plan de Desarrollo de la ciudad.
# .
# .
# .
# Gracias a la Corporación Opción Legal , todos los actores, comunidades e instituciones, por el apoyo y el impulso en estas actividades, como siempre seguimos avanzando por la integración en este país que nos brindan muchas oportunidades de desarrollo.
# .
# .
# .
# #somoscolvenz
# #somoscolonia
# #SomosLaClave
# #CoordinaciónParaLaIntegración
# 12345 ---- 100% publication : 22 complete
# Me gusta: 7 personas
# 12345 ---- 100% publication : 22 complete
# Scroll 1/1: desplazado a 99122
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# JORNADA DE EVALUACIÓN DE VULNERABILIDAD POR LA WORLD VISION en el corregimiento de San Antonio de Prado. Se atendieron 83 cabeza de familia con una participación total de 150 personas a la convocatoria que además se comprometió para una segunda jornada.
# Gracias a @worldvisionco ,  todos los actores, comunidades e instituciones, por el apoyo y el impulso en estas actividades dirigidas a nuestra comunidad, como siempre seguimos avanzando por la integración en este país que nos brindan muchas oportunidades de desarrollo.
# .
# .
# .
# @coalicionve
# @mesumocolombia
# #somoscolvenz
# #somoscoalicionvenezuela
# #somoscolonia
# #SomosLaClave
# #tesumas
# 12345 ---- 100% publication : 23 complete
# Me gusta: 8 personas
# 12345 ---- 100% publication : 23 complete
# Scroll 1/1: desplazado a 104315
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# Más del encuentro del Enviado especial de la OIM en su visita a la ciudad de Medellín.
# En esta visita, las organizaciones compartieron sus experiencias, planes de trabajo para este 2024 y las expectativas para el siguiente trimestre en conjunto con las grandes organizaciones que al igual que la OIM, impulsan los programas y los proyectos sociales y de integración dirigidos a la población migrante y retornada.
# Colvenz también invitó a este encuentro a los emprendedores que salieron beneficiados con el Concurso de Buenas Prácticas, para que ellos mismos compartieran el impacto positivo que ha tenido este fortalecimiento en sus vidas.
# @oimcolombia
# @coalicionve
# #somoscolvenz
# #somoscolonia
# #SomosLaClave
# #Venezolanosenelexterior
# #migracionvenezolana
# #venezolanosenelextranjero
# #venezolanosporelmundo
# 12345 ---- 100% publication : 24 complete
# Me gusta: 7 personas
# Me encanta: 1 persona
# 12345 ---- 100% publication : 24 complete
# Scroll 1/1: desplazado a 109010
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# ATENCIÓN COMUNIDAD!
#  CANADA BUSCA TÚ TALENTO
# Asociación Salto Ángel y Coalición por Venezuela informa sobre la oportunidad de optar por un empleo y permanencia en Canadá .
# Tenemos la orientación necesaria para que puedas aplicar al programa Catálogo de Talentos, debes cumplir con los siguientes requisitos:
# - Ser migrante (con estatus regular o irregular) o condición de refugiado.
# - Tener conocimientos en inglés (intermedio, nivel B2)
# - Ser profesional en cualquier área (no limitante) sobre todo tener experiencia en cualquier oficio
# Accede al Pre - Registro por este link https://forms.office.com/r/nDsvZJhuXN o si estas en #instagram dale click al link de nuestra bio "Catálogo de Talentos - Canadá Hiring". También puedes escanear el código QR de la última imagen de esta publicación para ir directo a llenar el formulario.
# Y queda atento que a medida que vamos recolectando datos, haremos una convocatoria para una reunión informativa donde explicaremos los detalles y ayudaremos con todas las dudas que tengas sobre los requisitos, la aplicación, etc.
# Colaboradores para Más info:
# @arles_264
# @tonivitola
# Un proyecto de @coalicionve con @jumpstartrefugee y @talentbeyondboundaries
# #SomosInclusión
# #SomosLaClave
# 12345 ---- 100% publication : 25 complete
# Me gusta: 5 personas
# 12345 ---- 100% publication : 25 complete
# Scroll 1/1: desplazado a 114381
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# Felicidades al presidente de Colvenz por ser reelecto como Coordinador País Colombia de Coalición por Venezuela 2024
# Las organizaciones miembros con presencia en 22 países de América, el Caribe y Europa eligieron a los coordinadores que los representaran ante la Coordinación General de @coalicionve en éste período 2024.
# Los coordinadores electos inciden en la toma de decisiones, así como también coordinan acciones, convocan reuniones y son portavoz sobre informaciones de interés para las organizaciones del país que representan.
# .
# .
# .
# #SomosLaClave
# #SomosIntegración
# #SomosCoalicionVE
# #venezolanosencolombia
# #venezolanosenelextranjero
# #colombia
# 12345 ---- 100% publication : 26 complete
# Me gusta: 6 personas
# Me encanta: 2 personas
# 12345 ---- 100% publication : 26 complete
# Scroll 1/1: desplazado a 118898
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# ATENCIÓN COMUNIDAD:
# PRIMERA JORNADA DE VACUNACIÓN NACIONAL.
# ¿Quiénes se pueden vacunar?
# - Niños y niñas menores de 6 años para esquema regular.
# - Niños y niñas de 9 años para la vacuna contra el Virus del Papiloma Humano.
# - Dosis adicional de Sarampión y Rubeola para niños y niñas nacidos a partir de enero de 2010.
# - Vacuna contra la Influenza para niños y niñas de 7 meses a 23 meses que requieran la segunda dosis, población mayor de 3 años en adelante y madres gestantes a partir de la semana 14.
# FECHA: 2/01/2024
# encuentra el punto más cercano a tu localidad en las imágenes de este post.
# De 8:00 a.m. - 4:00 p.m.
# .
# .
# @esemetrosalud
# @coalicionve
# @mesumocolombia
# #somoscolvenz
# #somoscoalicionvenezuela
# #somoscolonia
# #SomosLaClave
# #TeSumas
# #venezolanosencolombia
# #migracioncolombia
# 12345 ---- 100% publication : 27 complete
# 123 ---- 100% publication : 27 complete
# Scroll 1/1: desplazado a 124197
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# JORNADA DE ENTREGA DE REGALOS A LOS NIÑOS DE LA COMUNIDAD DE URABÁ.
# Tuvimos la oportunidad en La sub región de Urabá municipio Apartado Antioquia de impactar 100 niños migrantes en situación vulnerable en representación de COLVENZ.
# .
# Queremos agradecer a todos los actores, a la comunidad de Urabá y en especial a nuestra Lider de la sub región Urabá-Darién, por el apoyo y el impulso en estas actividades dirigidas a nuestra comunidad, como siempre seguimos avanzando por la integración en este país que nos brindan muchas oportunidades de desarrollo.
# .
# @coalicionve
# @mesumocolombia
# #somoscolvenz
# #somoscoalicionvenezuela
# #somoscolonia
# #SomosLaClave
# #tesumas
# 12345 ---- 100% publication : 28 complete
# Me gusta: 8 personas
# 12345 ---- 100% publication : 28 complete
# Scroll 1/1: desplazado a 129105
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# Queridos amigos y amigas, comunidad migrante, con todos los retos, proyectos y avances de este año, queremos agradecerles por su solidaridad y apoyo a nuestra organización. Gracias a ustedes, hemos podido brindar asistencia a una gran parte de la comunidad de acogida, retornados y migrantes. Su generosidad nos ha permitido apoyar a muchos en sus proyectos, emprendimientos, aliviar sus preocupaciones y mucho más
# Sabemos que el próximo año será otro gran desafío, pero también una oportunidad para seguir trabajando por nuestros hermanos. Por eso, les pedimos que no nos abandonen, que sigan siendo parte de esta organización, que nos ayuden a difundir nuestro trabajo y a conseguir más recursos y aliados. Juntos podemos hacer la diferencia.
# Les deseamos unas felices fiestas y un próspero año nuevo, lleno de esperanza y paz. Que Dios los bendiga. ¡Un abrazo fraterno!
# .
# #Navidad #Esperanza #Agradecimiento #MigrantesVenezolanos #UnidosEnLaDistancia
# 12345 ---- 100% publication : 29 complete
# Me gusta: 9 personas
# Me encanta: 3 personas
# 12345 ---- 100% publication : 29 complete
# Scroll 1/1: desplazado a 131013
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# Y así nos reunimos para conmemorar el Día Internacional del Migrante. Un día de celebración para nuestra Organización, acompañados de nuestros aliados, equipo de trabajo, voluntarios, colaboradores, instituciones, y muchas personas quienes han apoyado esta misión de poder encontrar las vías hacia la estabilidad, mejor calidad de vida y visibilidad de los Migrantes. Hemos hecho esta larga caminata juntos, trabajando en distintos proyectos, que como nos narra el presidente de #COLVENZ, @arles_264 comenzó como un sueño, que ahora es una realidad.
# .
# Agradecemos a todas las OBCs, Organizaciones, Instituciones, personas que han sido no solo testigo, sino parte de este gran sueño que ha crecido, solidificando las bases que nos impulsa ahora, para encontrarnos bajo una misma etiqueta: #SomosLaClave.
# Agradecimiento especial a los representantes que nos acompañaron en nuestro 7mo. Aniversario:
# @acnur
# @oimcolombia
# @alcaldiademed
# @usaidcolombia
# @mercycorpscolombia
# @corpoayudahumanitaria
# @corpopcionlegal
# @aidforaidscolombia
# @acdivoca_colombia
# @mesumocolombia
# @coalicionve
# Proyecto Integra de USAID
# Centro Intégrate USAID
# Iglesia Luterana Confesional, la Santísima Trinidad
# .
# .
# .
# #somoscolvenz
# #somoscolonia
# #SomosLaClave
# #Venezolanosenelexterior
# #migracionvenezolana
# #venezolanosenelextranjero
# #venezolanosporelmundo
# 12345 ---- 100% publication : 30 complete
# Me gusta: 4 personas
# Me encanta: 3 personas
# Me importa: 2 personas
# 12345 ---- 100% publication : 30 complete
# Scroll 1/1: desplazado a 136929
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# ¡Atención Comunidad, Alerta de fraude!
# .
# En redes sociales circula una campaña ofreciendo dinero. Es una estafa. No caigas y no la compartas
# .
# Sigue nuestros canales oficiales y cuídate de la desinformación. Cuida de los tuyos también y comparte este post.
# #Venezolanosenelexterior #migracionvenezolana #venezolanosenelextranjero #venezolanosporelmundo #desaparecidos #missing
# 12345 ---- 100% publication : 31 complete
# 123 ---- 100% publication : 31 complete
# Scroll 1/1: desplazado a 141590
# 1234 ---- 100%  contenent has no text, is photo,video or post withoout text
# 123 ---- 100% publication : 33 complete
# 123 ---- 100%
#  Buenas tardes como hago para saber en q estatus se encuentra mi ppt desde el año pasado q hice el registro del rumv y fui a la cita biometrica y hasta ahora nada q me sale he entrado a la página y consulto y nada ne dicen q todavía esta en transmite
# Scroll 1/1: desplazado a 144298
# 1234 ---- 100%  contenent has no text, is photo,video or post withoout text
# Me gusta: 4 personas
# Me importa: 1 persona
# 12345 ---- 100% publication : 35 complete
# Scroll 1/1: desplazado a 148741
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# De acuerdo con el Grupo Internacional Sobre Flujos Migratorios Mixtos, en 2021 casi *150 mil refugiadxs y migrantes venezolanxs habían llegado a la ciudad*.
# ¿Cómo fue su proceso de acogida? _¿Y cómo está recibiendo Medellín a las personas migrantes que han llegado desde entonces?_
# Acompáñanos en este #CaféDeCiudad donde queremos conversar sobre los retos, condiciones y garantías de dignidad para quienes llegan a Medellín.
#  Viernes 17 de febrero 2023
#  4:00 p.m.
#  Terminal del Norte - Entrada por el acopio de taxis
#  Transmisión por el FB Live de *Lunes de Ciudad*
# 12345 ---- 100% publication : 36 complete
# Me gusta: 1 persona
# 12345 ---- 100% publication : 36 complete
# Scroll 1/1: desplazado a 154573
# 1234 ---- 100%  contenent has no text, is photo,video or post withoout text
# Me gusta: 13 personas
# Me encanta: 1 persona
# 12345 ---- 100% publication : 38 complete
# 123 ---- 100%
#  Felicidades por su entrega y Don de servicio.
# 123 ---- 100%
#  Buenas tardes , necesito para mañana dos modelos para corte de cabello gratis . Dos hombres . Hora de 9 am a 1 PM ) lugar Medellín parque periodista . Whatsapp 3104617336
# Scroll 1/1: desplazado a 156180
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# Para Ávila Asesoría es un gusto poder asesorarte en:
# El despegue de tu emprendimiento y el recorrido de tu camino como empresario.
# Tus inquietudes en derecho laboral.
# Elaboración de documentación legal.
# Y el apoyo en consultas y trámites para emigrantes.
# Nuestro Consultorio Jurídico y Contable cuenta con 14 años de experiencia.
# Atención en Venezuela y Colombia.
# Si deseas contactarnos por favor escríbenos directamente al WhatsApp +573016772763 / +584143358168
# 12345 ---- 100% publication : 39 complete
# Me gusta: 6 personas
# Me encanta: 1 persona
# 12345 ---- 100% publication : 39 complete
# 123 ---- 100%
#  Hola me podrías ayudar con unos trámites
# Scroll 1/1: desplazado a 160810
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# #SomosCorazónDobleTricolor #VenezolanosenCali
# 12345 ---- 100% publication : 40 complete
# Me gusta: 13 personas
# 12345 ---- 100% publication : 40 complete
# Scroll 1/1: desplazado a 165295
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# #LaRadiosNosUne
# 12345 ---- 100% publication : 41 complete
# Me gusta: 1 persona
# 12345 ---- 100% publication : 41 complete
# Scroll 1/1: desplazado a 168907
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# Ellos son absolutamente increíbles
# .
# Servicio médico veterinario a domicilio, disminuye el estrés de tu mascota y aprovecha tu tiempo.
# .
# .
# Ofrecemos servicios médico veterinarios a domicilios, de esta forma tu mascota estará mucho más tranquila y relajada al momento del manejo.
# Hacemos: fisioterapia y rehabilitación.
# Consulta general.
# Exámenes.
# Certificados de salud par viajes nacional e internacional.
# Realizamos examen de titulación de anticuerpos para rabia (Universidad de Kansas).
# Cuidamos a tu mascota si necesitas salir de viaje (varias modalidades)
# Pregunta por nuestros servicios: WhatsApp 3127642967
# .
# .
# .
# .
# #veterinario #veterinarioadomicilio #vetererinariaencasa #veterinary #veterinariaperrosygatos #vegerinariabogota #vetencasa #veteencasa #vetedomicilio #vetdomicilo #bogota #cedritos #pasadena #mazuren #sancipriano #veterinariabogota #veterinarias
# 12345 ---- 100% publication : 42 complete
# Me gusta: 2 personas
# 12345 ---- 100% publication : 42 complete
# 123 ---- 100%
#  Up
# Scroll 1/1: desplazado a 171579
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# CALI
# 12345 ---- 100% publication : 43 complete
# Me gusta: 1 persona
# 12345 ---- 100% publication : 43 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# Atención....
# 12345 ---- 100% publication : 44 complete
# Me gusta: 32 personas
# 12345 ---- 100% publication : 44 complete
# Scroll 1/1: desplazado a 180464
# 1234 ---- 100%  contenent has no text, is photo,video or post withoout text
# Me gusta: 16 personas
# Me importa: 2 personas
# Me encanta: 1 persona
# 12345 ---- 100% publication : 46 complete
# 123 ---- 100%
#  Gracias Yanira si aquí capacitación de nuestro equipo de trabajo para un mejor desempeño de cada una de sus funciones.
# Yenson te estamos esperando
# 123 ---- 100%
#  Un abrazo enorme
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# Oportunidad para migrantes venezolanos y colombianos retornados de capacitarse y certificarse en Colombia en el área de la Tecnología de la Información y de la Comunicación. Cupos Limitados.
# 12345 ---- 100% publication : 47 complete
# Me gusta: 8 personas
# 12345 ---- 100% publication : 47 complete
# Scroll 1/1: desplazado a 188763
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# Información directa desde Migración Colombia
# 12345 ---- 100% publication : 48 complete
# Me gusta: 3 personas
# 12345 ---- 100% publication : 48 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# #Deberesyderechosvandelamano
# 12345 ---- 100% publication : 49 complete
# Me gusta: 2 personas
# 12345 ---- 100% publication : 49 complete
# Scroll 1/1: desplazado a 196398
# 1234 ---- 100%  contenent has no text, is photo,video or post withoout text
# 123 ---- 100% publication : 51 complete
# Scroll 1/1: desplazado a 198865
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
#
# 12345 ---- 100% publication : 52 complete
# 123 ---- 100% publication : 52 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# Re - Imaginemos Juntos
# 12345 ---- 100% publication : 53 complete
# Me gusta: 2 personas
# 12345 ---- 100% publication : 53 complete
# Scroll 1/1: desplazado a 206357
# 1234 ---- 100%  contenent has no text, is photo,video or post withoout text
# Me gusta: 2 personas
# Me encanta: 1 persona
# Me entristece: 1 persona
# 12345 ---- 100% publication : 55 complete
# Scroll 1/1: desplazado a 209997
# 1234 ---- 100%  contenent has no text, is photo,video or post withoout text
# Me gusta: 24 personas
# 12345 ---- 100% publication : 57 complete
# Scroll 1/1: desplazado a 214271
# 1234 ---- 100%  contenent has no text, is photo,video or post withoout text
# Me gusta: 2 personas
# 12345 ---- 100% publication : 59 complete
# Scroll 1/1: desplazado a 217830
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# ENCUESTA MIGRANTES VENEZOLANOS EN ANTIOQUIA CON RESPECTO A LA  AFILIACIÓN AL SISTEMA DE SALUD
# INVITAMOS A LA POBLACION VENEZOLANA EN ANTIOQUIA A REALIZAR ESTS ENCUESTA. El desarrollo de esta es de suma importancia para la planeación, ejecución y desarrollo de estrategias que tendrán como objetivo la afiliación de la población migrante venezolana en condición migratoria regular al SGSSS, además el de caracterizar la situación de los migrantes venezolanos con respecto a este tema.
# ¡CON TU AYUDA PODEMOS LOGRARLO!
# 12345 ---- 100% publication : 60 complete
# Me gusta: 18 personas
# Me importa: 1 persona
# 12345 ---- 100% publication : 60 complete
# Scroll 1/1: desplazado a 219995
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# Desde el Centro Nacional de Consultoría buscamos *HOMBRES Y MUJERES VENEZOLANOS mayores de 18 años estratos 1, 2, 3 y 4 que vivan hace más de 6 meses en Colombia (a nivel nacional), para GRUPOS FOCALES VIRTUALES* a realizar en las dos siguientes semanas si están interesados diligenciar el formulario en el siguiente link: https://forms.gle/9n2moWRK6YtzzmG8A
# Con incentivo
# 12345 ---- 100% publication : 61 complete
# Me gusta: 23 personas
# Me encanta: 2 personas
# 12345 ---- 100% publication : 61 complete
# Scroll 1/1: desplazado a 227259
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# Encuesta de importancia para la población migrante en Colombia
# 12345 ---- 100% publication : 62 complete
# Me gusta: 10 personas
# 12345 ---- 100% publication : 62 complete
# Scroll 1/1: desplazado a 229888
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# Atención...
# 12345 ---- 100% publication : 63 complete
# Me gusta: 9 personas
# Me encanta: 1 persona
# 12345 ---- 100% publication : 63 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# Vinimos a aportar y muchos vamos a quedarnos, luchamos por una integración armoniosa y productiva. #CorazónDobleTricolor #ColoniaVenezolanaenColombia #SoyColvenz #SoyUtraven #SomosCoaliciónporVenezuela Gracias Revista Semana por contribuir en visibilizar nuestra lucha.
# 12345 ---- 100% publication : 64 complete
# Me gusta: 16 personas
# Me encanta: 4 personas
# 12345 ---- 100% publication : 64 complete
# Scroll 1/1: desplazado a 237015
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# Rueda informativa de Migración Colombia
# 12345 ---- 100% publication : 65 complete
# Me gusta: 8 personas
# Me encanta: 1 persona
# 12345 ---- 100% publication : 65 complete
# Scroll 1/1: desplazado a 242679
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# Atentos...
# 12345 ---- 100% publication : 66 complete
# Me gusta: 10 personas
# Me encanta: 1 persona
# 12345 ---- 100% publication : 66 complete
# Scroll 1/1: desplazado a 244367
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# Preguntas y Respuestas sobre el nuevo Estatuto Temporal de Protección para Migrantes Venezolanos.
# 12345 ---- 100% publication : 67 complete
# Me gusta: 3 personas
# 12345 ---- 100% publication : 67 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%  contenent has no text, is photo,video or post withoout text
# Me gusta: 6 personas
# Me encanta: 2 personas
# Me importa: 1 persona
# 12345 ---- 100% publication : 69 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%  contenent has no text, is photo,video or post withoout text
# Me gusta: 1 persona
# 12345 ---- 100% publication : 71 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# Información de Importancia
# 12345 ---- 100% publication : 72 complete
# Me gusta: 13 personas
# 12345 ---- 100% publication : 72 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# Último Facebook Live de Migración Colombia del año 2020
# 12345 ---- 100% publication : 73 complete
# Me gusta: 4 personas
# 12345 ---- 100% publication : 73 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# Gracias Dejusticia
# 12345 ---- 100% publication : 74 complete
# Me gusta: 7 personas
# 12345 ---- 100% publication : 74 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# Muchas gracias Dejusticia!
# 12345 ---- 100% publication : 75 complete
# Me gusta: 6 personas
# Me encanta: 4 personas
# 12345 ---- 100% publication : 75 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# Sumamente agradecida con @Dejusticia por su invaluable apoyo y su hermoso reconocimiento. Muchas gracias.
# 12345 ---- 100% publication : 76 complete
# Me gusta: 3 personas
# Me encanta: 2 personas
# 12345 ---- 100% publication : 76 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%  contenent has no text, is photo,video or post withoout text
# Me gusta: 2 personas
# Me encanta: 1 persona
# Me asombra: 1 persona
# 12345 ---- 100% publication : 78 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%  contenent has no text, is photo,video or post withoout text
# Me gusta: 8 personas
# Me encanta: 1 persona
# 12345 ---- 100% publication : 80 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# ...
# 12345 ---- 100% publication : 260 complete
# 123 ---- 100% publication : 260 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# Mañana estaremos nuevamente acompañando esta gran iniciativa de Comfama, en la Bodega en la Calle 34 # 45a - 18
# 12345 ---- 100% publication : 261 complete
# Me gusta: 8 personas
# Me encanta: 1 persona
# 12345 ---- 100% publication : 261 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%  contenent has no text, is photo,video or post withoout text
# Me gusta: 4 personas
# 12345 ---- 100% publication : 263 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# De Interés!!
# 12345 ---- 100% publication : 264 complete
# Me gusta: 3 personas
# 12345 ---- 100% publication : 264 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# Primera Feria Gastronómica Cultural Colombo Venezolana en la Ciudad de Pasto.
# 12345 ---- 100% publication : 265 complete
# Me gusta: 7 personas
# 12345 ---- 100% publication : 265 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
#
# 12345 ---- 100% publication : 266 complete
# Me gusta: 1 persona
# 12345 ---- 100% publication : 266 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# No te pierdas este lindo evento. Contribuye con la ciudad que te recibió.
# 12345 ---- 100% publication : 267 complete
# Me gusta: 5 personas
# 12345 ---- 100% publication : 267 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%  contenent has no text, is photo,video or post withoout text
# Me gusta: 8 personas
# 12345 ---- 100% publication : 269 complete
# 123 ---- 100%
#  Éxitos para todos soy una Colombiana que desea todo lo mejor para los Venezolanos. Dios los bendiga
# 123 ---- 100%
#  El 27 de Sep habrá nuevamente inscripción para la bola de empleo
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%  contenent has no text, is photo,video or post withoout text
# Me gusta: 4 personas
# 12345 ---- 100% publication : 271 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%  contenent has no text, is photo,video or post withoout text
# Me gusta: 2 personas
# Me encanta: 2 personas
# 12345 ---- 100% publication : 273 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# Comfama nos hace esta invitación para el día martes
# 12345 ---- 100% publication : 274 complete
# Me gusta: 10 personas
# Me encanta: 5 personas
# 12345 ---- 100% publication : 274 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%  contenent has no text, is photo,video or post withoout text
# Me gusta: 2 personas
# 12345 ---- 100% publication : 276 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# Curso Manipulador de Alimentos
# 12345 ---- 100% publication : 277 complete
# Me gusta: 4 personas
# Me encanta: 1 persona
# 12345 ---- 100% publication : 277 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%  contenent has no text, is photo,video or post withoout text
# 123 ---- 100% publication : 279 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%  contenent has no text, is photo,video or post withoout text
# Me gusta: 4 personas
# 12345 ---- 100% publication : 281 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# Virgen de Coromoto, patrona de Venezuela, bendice la acción evangelizadora de la Iglesia en nuestra patria para que sea fortaleza y defensa de la fe de tus hijos y comienzo de una renovación de las costumbres cristianas. Imagen de @Olivarescfc  #venezolanosunidosencolombia
# 12345 ---- 100% publication : 282 complete
# Me gusta: 7 personas
# Me encanta: 2 personas
# 12345 ---- 100% publication : 282 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%  contenent has no text, is photo,video or post withoout text
# Me gusta: 3 personas
# 12345 ---- 100% publication : 284 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
#
# 12345 ---- 100% publication : 285 complete
# Me gusta: 2 personas
# 12345 ---- 100% publication : 285 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%  contenent has no text, is photo,video or post withoout text
# Me gusta: 3 personas
# 12345 ---- 100% publication : 287 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%  contenent has no text, is photo,video or post withoout text
# Me gusta: 4 personas
# 12345 ---- 100% publication : 289 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# Sabemos que es difícil la situación en que te encuentras, pero analizar y planear muy bien tu proceso migratorio te evitara muchas dificultades y ayudara en tu adaptación al país que llegues #colvenz #venezolanosencolombia
# 12345 ---- 100% publication : 290 complete
# Me gusta: 3 personas
# Me encanta: 1 persona
# 12345 ---- 100% publication : 290 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%  contenent has no text, is photo,video or post withoout text
# Me gusta: 6 personas
# Me encanta: 2 personas
# 12345 ---- 100% publication : 292 complete
# 123 ---- 100%
#  Gracias Colombia
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%  contenent has no text, is photo,video or post withoout text
# Me gusta: 2 personas
# 12345 ---- 100% publication : 294 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# Únete con tus amigos y apoya esta jornada de ayuda.
# 12345 ---- 100% publication : 295 complete
# Me gusta: 5 personas
# 12345 ---- 100% publication : 295 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# ECOPETROL S.A anuncia que están buscando personas creativas, a quienes les apasione trabajar en equipo y asumir nuevos desafíos para contribuir al fortalecimiento de la producción de petróleo en el país. Ingresa a  http://www.convocatoriaecopetrol2018.com . ¡Postúlate y comparte!
# Buscan profesionales con experiencia en Geociencias, Exploración, Perforación y Completamiento, Yacimientos, Recobro Mejorado, Producción, No Convencionales, Proyectos de Oil & Gas, Finanzas, Nuevos Negocios, Estrategia y Digital.
# ENTREVISTAS EN BOGOTÁ – BUENOS AIRES – CIUDAD DE MÉXICO - HOUSTON
# 12345 ---- 100% publication : 296 complete
# Me gusta: 6 personas
# Me encanta: 1 persona
# 12345 ---- 100% publication : 296 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%  contenent has no text, is photo,video or post withoout text
# Me gusta: 8 personas
# Me encanta: 3 personas
# 12345 ---- 100% publication : 298 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
#
# 12345 ---- 100% publication : 299 complete
# 123 ---- 100% publication : 299 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%  contenent has no text, is photo,video or post withoout text
# Me gusta: 4 personas
# 12345 ---- 100% publication : 301 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# Venezolanos trabajando duro y haciendo las cosas bien hechas: frente al CEOH en Medellín, súper deliciosas empanadas: carne mechada, pabellón, etc. Educados, amables, muy limpios y cuidadosos con la higiene !!
# 12345 ---- 100% publication : 302 complete
# Me gusta: 15 personas
# 12345 ---- 100% publication : 302 complete
# 123 ---- 100%
#  Por la avenida Guayabal, a unas 4-5 cuadras de los Outlet. Frente al CEOH = Centro Empresarial Olaya Herrera, cerca del Aeropuerto Olaya Herrera ....
# 123 ---- 100%
#  Donde queda eso?
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%  contenent has no text, is photo,video or post withoout text
# 123 ---- 100% publication : 304 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# Voluntarios!!
# 12345 ---- 100% publication : 305 complete
# Me gusta: 6 personas
# Me encanta: 1 persona
# 12345 ---- 100% publication : 305 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%  contenent has no text, is photo,video or post withoout text
# Me gusta: 6 personas
# 12345 ---- 100% publication : 307 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# Gracias por la invitación al grupo... dios nos bendice a todos.... #losbuenosomosmas#
# 12345 ---- 100% publication : 308 complete
# 123 ---- 100% publication : 308 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%  contenent has no text, is photo,video or post withoout text
# Me gusta: 2 personas
# 12345 ---- 100% publication : 310 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%  contenent has no text, is photo,video or post withoout text
# Me gusta: 12 personas
# 12345 ---- 100% publication : 312 complete
# 123 ---- 100%
#  Que chévere....felicitaciones
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# Servicefast es una aplicación inteligente que conecta miles de personas con profesionales cerca de la localidad.
# https://colvenz.org/.../alianza-servicefast-y-colvenz.../
# 12345 ---- 100% publication : 313 complete
# Me gusta: 7 personas
# 12345 ---- 100% publication : 313 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# Grupo de la Colonia de Venezolanos en Colombia, con información sobre migración, salud, educación y otros temas de interés de la diaspora venezolana.
# Somos una comunidad organizada, tendiente a evitar estados de marginación o exclusión y garantizar, en consecuencia, la integración de los migrantes venezolanos a las distintas dimensiones de la vida económica, cultural, deportiva, política, entre otras, de su país anfitrión, la República de Colombia, de tal manera, que puedan no solo participar de los derechos y obligaciones que la Constitución y las demás normas establecen para los colombianos, sino aportar al necesario sincretismo que permitiría erigir una cultura binacional fundada en el respeto a la diferencia, la diversidad y la pluralidad como valores democráticos universales.
# Para publicidad por favor contactar a los administradores.
# Fan Page:  https://web.facebook.com/colvenz/
# Twitter: @Colonia_COLVENZ
# Instagram: @colvenz.oficial
# www.colvenz.org
# 12345 ---- 100% publication : 314 complete
# Me gusta: 5 personas
# Me encanta: 2 personas
# 12345 ---- 100% publication : 314 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# Jornada en el Carmen de Viboral
# 12345 ---- 100% publication : 315 complete
# Me gusta: 2 personas
# 12345 ---- 100% publication : 315 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%
# El botón 'Ver más' está presente en el contenedor.
# 1234 ---- 100% click performed
# LISTADO DE PRÓRROGAS POR RECLAMAR EN EL CONSULADO DE MEDELLIN (PLAZO HASTA EL 30 DE AGOSTO ANTES DE SER REGRESADOS AL SAIME EN VENEZUELA)
# PRÓRROGAS QUE SE ENCUENTRAN EN EL CONSULADO
# Laura Natacha Méndez Bruzon
# Luis Fernando Godoy Jaimes
# Rubén Darío Polanco Núñez
# Isabella Cristina Rivas Castellanos
# Zoe Marie Uscategui Oviedo
# Nora Carolina Angulo Herrera
# Martha Uriela Villegas Gómez
# Cristian Cipriani Restrepo
# Génesis Beatriz Mesa Ávila
# PRORROGA DE PASAPORTE
# Beronica Valero Rodríguez
# Francisco Javier Veliz Bermúdez
# Gabriel Hernando Méndez Guzmán
# Luis Gerardo Moreno Quintero
# Junior Asdrúbal Pérez Arteaga
# Andrea Marivi Dávila Martin
# Jhonder Rafael Vásquez Reinoso
# Karen Yesenia González Hernández
# Reyna Milagros Paz Valero
# Jossue Daniel López Guedez
# José Domingo Núñez Izaguirre
# Diego Alejandro Subero Gómez
# Carlos Junior Monsalve Rojas
# Anais Alejandra Guillen Silva
# Douglas Rafael Yajuris Guanipa
# Juan Carlos Miguez Fernández
# Ana Adelfa Mazo De Gutiérrez
# Isis Marina Daza Peña
# Marcos Serfaty Rivera
# Lismar Del Carmen Oliveros Gallardo
# Jorge Alberto Amaya Urrego
# Lila Renata Narváez
# María Josefina Tovar Paredes
# Ervimar José Aguilera Méndez
# Hugo Manuel Leal Molina
# Auxiliadora Galicia Paredes
# Juan de Jesús Quintero Ángel
# Nicolás Andrés Rada Abrams
# Victor José Pombo Sonderblohm
# Zuly Antonieta Quebedo de Pérez
# NOTA: Las personas que se encuentran en este listado deben acercarse al consulado en el horario de 8:00 am a 12:m., con los siguientes documentos: Fotocopia de la cédula, fotocopia del pasaporte, fotocopia del acta de nacimiento.
# El pasaporte y la cédula en físico original y el valor de 80 USD al cambio en pesos colombianos.
# Las personas que hayan tramitado pasaporte a partir del año 2016 y cancelaron el valor de los 80 USD, deberán traer la tirilla de pago, con la cual queda exento de pago de estos 80 USD.
# 12345 ---- 100% publication : 316 complete
# 123 ---- 100% publication : 316 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%  contenent has no text, is photo,video or post withoout text
# Me gusta: 1 persona
# Me enfada: 1 persona
# 12345 ---- 100% publication : 318 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%
# El botón 'Ver más' no está presente en este contenedor.
# 1234 ---- 100%
# Grupo de la Colonia de Venezolanos en Colombia, con información sobre migración, salud, educación y otros temas de interés de la diaspora venezolana.
# Para publicidad por favor contactar a los administradores.
# 12345 ---- 100% publication : 319 complete
# Me gusta: 1 persona
# 12345 ---- 100% publication : 319 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%  contenent has no text, is photo,video or post withoout text
# Me gusta: 1 persona
# 12345 ---- 100% publication : 321 complete
# No hay más contenido para cargar. Deteniendo el scroll.
# 1234 ---- 100%  NO MORE PUBLICATIONS IN THE GROUP
#  Message: Unable to locate element: /html/body/div[1]/div/div[1]/div/div[3]/div/div/div[1]/div[1]/div[4]/div/div/div[2]/div/div/div[2]/div[2]/div[2]/div[322]/div/div/div/div/div/div/div/div/div/div[13]/div/div/div[2]/div; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16

# %%
#INICIO

# %%
'''ACCESO A EL POST DE INSTAGRAM AL CUAL SE LE EXTRAERAN LOS COMENTARIOS'''

driver.get(INSTAGRAM_URL)
# driver.maximize_window()
barra_carga(20)
print('Post Cargado')

# %%
''' 
VALIDACION 

Funcionamiento de acceso a la URL, navegacion y captura de segmentos del en X.Path
Prueba del Scroll y de la Estrategia de Espera para la carga de mensajes

'''

#ubicar el primer comentario que se encuentra en la pagina, es decir el primer
#contenedor dentro de contenedor macro, esto para tener el punto de referencia de :
#donde se encuentra el bloque de comentarios y donde inicia

# seccion_comments = '/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div/div['

seccion_comments     = '/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div['
                    
seccion_sub_comments = '/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[2]/div['

validacion_instagram(driver,seccion_comments)
barra_carga(20)

# %%
#UBICACIONES COMENTARIOS

# seccion_comments      = '/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div/div['
# displayName_comments  = '/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div/div[1]/div/div[2]/div/span/div/div/span[1]/div/a'

# displayName_comments(VALIDO)  = '/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div/div[2]/div/div[2]/div[1]/div[1]/div/div[1]/span[1]/span/div/a'


# comentario_usuario    = '/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div/div[1]/div/div[2]/div/span/div/span'
                        #   '/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div/div[2]/div/div[2]/div[1]/div[1]/div/div[2]/span'
                        #   '/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div/div[3]/div/div[2]/div[1]/div[1]/div/div[2]/span'

# %%
#VERSION 01

# #VARIABLES PARA EL SCRAPING
# comentarios_recorridos = list()
# centinela = True
# comment_interno = 1
# comment_externo = 1
# comment_total_respuestas = 3
# base_final = pd.DataFrame()

# while centinela == True:
#     try:
        
#     ##VALIDACION DE BLOQUE DE COMENTARIOS           
#         try:
#             driver.find_element(By.XPATH, value= '/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[1]/div/div[2]/div/span/div/div/span[1]/div/a/div/div/span')
#             print('Usuario Encontrado:')
#             time.sleep(3)
#         except:
#             pass

#     ## PRIMER NIVEL DE COMENTARIOS
#         # Level 1 comment principal
#         level = 1
#         # Detectar el DISPLAY NAME del usuario
#         try:
#             display_name = driver.find_element(By.XPATH, value = seccion_comments + str(comment_externo) + "]/div/div[2]/div/span/div/div/span[1]/div/a").text
            
#             username_thread = driver.find_element(by=By.PARTIAL_LINK_TEXT,value=display_name).get_attribute("href")
#             comment = driver.find_element(By.XPATH, value = seccion_comments + str(comment_externo) + "]/div/div[2]/div/span/div/span").text

#             print(display_name + '_bloque01_' + username_thread + comment)

#         except:
#             display_name = driver.find_element(By.XPATH, value = seccion_comments + str(comment_externo) + "]/div/div[2]/div[1]/div[1]/div/div[1]/span[1]/span/div/a").text

#             username_thread = driver.find_element(by=By.PARTIAL_LINK_TEXT,value=display_name).get_attribute("href")
#             comment = driver.find_element(By.XPATH, value = seccion_comments + str(comment_externo) + "]/div/div[2]/div[1]/div[1]/div/div[2]/span").text
            
#             print(display_name + '_bloque02_' + username_thread + comment)
        
#             try:
#                 '''Click Ver Respuesta'''
#                 ver_respuesta = driver.find_element(By.XPATH, value = seccion_comments + str(comment_externo + 1) + "]/div/div/span")
#                 ver_respuesta.click()
#                 comment_externo  = comment_externo + 1
#                 print('click realizado', comment_externo)
#                 time.sleep(5)

#     ### SEGUNDO NIVEL DE COMENTARIOS
#                 # while True:
#                 #     try:
#                 #         display_name_interno = driver.find_element(By.XPATH, value = seccion_comments + str(comment_externo) +']/ul/div[' + str(comment_interno) + ']/div/div[2]/div[1]/div[1]/div/div[1]/span[1]/span/div/a').text
#                 #         comment_int = driver.find_element(By.XPATH, value = seccion_comments + str(comment_externo) +'/ul/div/div/div[2]/div[1]/div[1]/div/div[2]/span').text

#                 #         user_name_interno = driver.find_element(by=By.PARTIAL_LINK_TEXT,value=display_name_interno).get_attribute("href") 
#                 #         print(user_name_interno,comment_externo,comment_interno,comment_int)
#                 #     except:    
#                 #         break
#                 #     comment_interno  = comment_interno + 1    
#             except: 
#                 pass
        


#     ##DATAFRAME CON COMENTARIOS
#         # Creacion de Dataframe con los datos de cada comentario, y la base previa 
#         d = {"level": level,"Instragram Post":INSTAGRAM_URL, "display_name": display_name, "username":username_thread, "comment":comment}
#         base_temporal = pd.DataFrame(data=d,index=[comment_externo])
#         base_final = pd.concat([base_final, base_temporal], ignore_index=True)
    

#     ##LOOP
#         # Actualizacion del loop para continuar con el recorrido
#         comentarios_recorridos.append(comment_externo)
#         comment_externo  = comment_externo + 1
        
        
#         print(comment_externo)
#         print("Acabé el comment " + str(comment_externo - 1) + ' perteneciente al usuario: ' + str(display_name) + '\n')
    
#         time.sleep(5)
        
#     except :
#         break
        

# print('CARGA COMPLETA')

# # driver.quit()

# base_final.to_excel('base_instagram_mutante_17.xlsx')

# %%
#VERSION 02

#VARIABLES PARA EL SCRAPING
comentarios_recorridos = list()
centinela = True
comment_interno = 1
comment_externo = 1
comment_respuestas = 1
comment_total_respuestas = 3

base_final = pd.DataFrame()

while centinela == True:
    try:
        
    ##VALIDACION DE BLOQUE DE COMENTARIOS           
        try:
            driver.find_element(By.XPATH, value= '/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[1 ]/div/div[2]/div/span/div/div/span[1]/div/a/div/div/span')
            print('Usuario Encontrado:')
            time.sleep(3)
        except:
            pass

    ## PRIMER NIVEL DE COMENTARIOS
        # Level 1 comment principal
        level = 1
        # Detectar el DISPLAY NAME del usuario
        try:
            display_name = driver.find_element(By.XPATH, value = seccion_comments + str(comment_externo) + "]/div/div[2]/div/span/div/div/span[1]/div/a").text
            
            username_thread = driver.find_element(by=By.PARTIAL_LINK_TEXT,value=display_name).get_attribute("href")
            comment = driver.find_element(By.XPATH, value = seccion_comments + str(comment_externo) + "]/div/div[2]/div/span/div/span").text

            print(display_name + '_bloque01_' + username_thread + comment)

        except:
                                                                 
            display_name = driver.find_element(By.XPATH, value = seccion_comments + str(2) + "]/div[" + str(comment_externo) + "]/div[1]/div/div[2]/div[1]/div[1]/div/div[1]/span[1]/span/div/a/div/div/span").text

            username_thread = driver.find_element(by=By.PARTIAL_LINK_TEXT,value=display_name).get_attribute("href")
            comment = driver.find_element(By.XPATH, value = seccion_comments + str(2) + "]/div[" + str(comment_externo) + "]/div[1]/div/div[2]/div[1]/div[1]/div/div[2]/span").text
            
            print(display_name + '_bloque02_' + username_thread + comment)
            
            try:
                '''Click Ver Respuesta'''
                ver_respuesta = driver.find_element(By.XPATH, value = seccion_sub_comments + str(comment_respuestas) + "]/div[2]/div/div/span")
                ver_respuesta.click()
                comment_respuestas  = comment_respuestas + 1
                print('click realizado', comment_respuestas)
                time.sleep(5)   

            except: 
                print("no_click")
                pass
        
        ### SEGUNDO NIVEL DE COMENTARIOS
        try:
       
            # while True:
            try:
                display_name_interno = driver.find_element(By.XPATH, value = seccion_sub_comments + str(comment_respuestas) + "]/div[2]/ul/div[" + str(comment_respuestas + 1) + "]/div/div[2]/div[1]/div[1]/div/div[1]/span[1]/span/div/a/div/div/span").text
                # comment_int = driver.find_element(By.XPATH, value = seccion_comments + str(comment_externo) +'/ul/div/div/div[2]/div[1]/div[1]/div/div[2]/span').text

                user_name_interno = driver.find_element(by=By.PARTIAL_LINK_TEXT,value=display_name_interno).get_attribute("href") 
                print(user_name_interno)
            except: 
                print('intento')   
                pass
    #             #     comment_interno  = comment_interno + 1 
            
        except: 
            pass
        
    ##DATAFRAME CON COMENTARIOS
        # Creacion de Dataframe con los datos de cada comentario, y la base previa 
        d = {"level": level,"Instragram Post":INSTAGRAM_URL, "display_name": display_name, "username":username_thread, "comment":comment}
        base_temporal = pd.DataFrame(data=d,index=[comment_externo])
        base_final = pd.concat([base_final, base_temporal], ignore_index=True)
    

    ##LOOP
        # Actualizacion del loop para continuar con el recorrido
        comentarios_recorridos.append(comment_externo)
        comment_externo  = comment_externo + 1
        
        
        print(comment_externo)
        print("Acabé el comment " + str(comment_externo - 1) + ' perteneciente al usuario: ' + str(display_name) + '\n')
    
        time.sleep(5)
        
    except :
        break
        

print('CARGA COMPLETA')

# driver.quit()

# base_final.to_excel('base_instagram_mutante_18.xlsx')

# %%
#   ### SEGUNDO NIVEL DE COMENTARIOS
#                 while True:
#                     try:
#                         display_name_interno = driver.find_element(By.XPATH, value = seccion_sub_comments + str(comment_respuestas) + "]/div[2]/ul/div[" + str(comment_respuestas + 1) + "]/div/div[2]/div[1]/div[1]/div/div[1]/span[1]/span/div/a/div/div/span").text
#                         # comment_int = driver.find_element(By.XPATH, value = seccion_comments + str(comment_externo) +'/ul/div/div/div[2]/div[1]/div[1]/div/div[2]/span').text

#                         user_name_interno = driver.find_element(by=By.PARTIAL_LINK_TEXT,value=display_name_interno).get_attribute("href") 
#                         print(user_name_interno)
#                     except:    
#                         pass
#     #             #     comment_interno  = comment_interno + 1

# %%
# mut01 = pd.read_excel('base_instagram_mutante_01.xlsx')
# mut02 = pd.read_excel('base_instagram_mutante_02.xlsx')
# mut03 = pd.read_excel('base_instagram_mutante_03.xlsx')
# mut04 = pd.read_excel('base_instagram_mutante_04.xlsx')
# mut05 = pd.read_excel('base_instagram_mutante_05.xlsx')
# mut06 = pd.read_excel('base_instagram_mutante_06.xlsx')
# mut07 = pd.read_excel('base_instagram_mutante_07.xlsx')
# mut08 = pd.read_excel('base_instagram_mutante_08.xlsx')
# mut09 = pd.read_excel('base_instagram_mutante_09.xlsx')
# mut10 = pd.read_excel('base_instagram_mutante_10.xlsx')
# mut11 = pd.read_excel('base_instagram_mutante_11.xlsx')
# mut12 = pd.read_excel('base_instagram_mutante_12.xlsx')
# mut13 = pd.read_excel('base_instagram_mutante_13.xlsx')
# mut14 = pd.read_excel('base_instagram_mutante_14.xlsx')
# mut15 = pd.read_excel('base_instagram_mutante_15.xlsx')
# mut16 = pd.read_excel('base_instagram_mutante_16.xlsx')
mut17 = pd.read_excel('base_instagram_mutante_17.xlsx')
mut18 = pd.read_excel('base_instagram_mutante_18.xlsx')


# base_consolidada_instagram_mutante = pd.concat([mut01,mut02,mut03,mut04,mut05,mut06,
#                                                 mut07,mut08,mut09,mut10,mut11,mut12,
#                                                 mut13,mut14,mut15,mut16])

base_consolidada_instagram_mutante_02 = pd.concat([mut17,mut18])

base_consolidada_instagram_mutante_02.to_excel('base_consolidada_instagram_mutante_02.xlsx',index=False)
