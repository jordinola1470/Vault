# %%
#MODULOS DE SELENIUM
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.options import Options

from selenium.webdriver.firefox.options import Options
from selenium.webdriver.firefox.service import Service



from datetime import datetime

#MODULOS SECUNDARIOS
import pandas as pd
import numpy as np
import pyautogui
import os
import time
import ssl
import sys
import traceback
import re

#MODULO ALERTAS DESACTIVADAS
import warnings
warnings.filterwarnings('ignore')

#MODULO PROPIOS
from utils import modelamiento,limpiar_comentarios_

# %%
# try:
#     # Obtener tamaño del monitor
#     ancho, alto = pyautogui.size()

#     while True:
#         # Posición actual del cursor
#         x, y = pyautogui.position()

#         # Cálculo proporcional
#         porcentaje_x = x / ancho
#         porcentaje_y = y / alto

#         print(
#             f"Posición: X={x}, Y={y} | "
#             f"Relativo: X={porcentaje_x:.2%}, Y={porcentaje_y:.2%}",
#             end="\r"
#         )

#         time.sleep(0.1)

# except KeyboardInterrupt:
#     print("\nDetenido por el usuario.")

# %%
# lista_url = [
#     "https://www.instagram.com/reel/DJFlmTks4bv/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA===",
#     "https://www.instagram.com/reel/DJFjzGSPmoW/?igsh=bTI2bzM4NWJrczdh",
#     "https://www.instagram.com/p/DJFFVOUB8VC/?igsh=Ym5razRxaGFmeHo=",
#     "https://www.instagram.com/p/DJE80WwpfSA/?igsh=cmE4Zm96czhhNTE0",
#     "https://www.instagram.com/reel/DJEztf8vb7r/?igsh=MWdmajQwMDUyMnR4cQ==",
#     "https://www.instagram.com/p/DJE-wEvRJPN/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA==",
#     "https://www.instagram.com/p/DJEgnaYtcst/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA==",
#     "https://www.instagram.com/reel/DJEuTRSt_m1/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA==",
#     "https://www.instagram.com/reel/DJFY8RdNlVe/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA==",
#     "https://www.instagram.com/reel/DJDa4C-C6-S/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA==",
#     "https://www.instagram.com/p/DJFFIA9xIu5/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA=="
# ]

# %% [markdown]
# ### VERSION VENTANAS DIFERENTES

# %%
def ManagerInstagramScrapper_version (url,medio):

    # # Configuracion Chrome
    # chrome_options = Options()
    # # chrome_options.add_argument(f"--user-agent={random_user_agent}")
    # chrome_options.add_argument("--incognito")  # Modo incógnito
    # chrome_options.add_argument("--disable-cache")  # Deshabilitar la caché
    # chrome_options.add_argument("--disable-application-cache")  # Deshabilitar caché de aplicaciones
    # chrome_options.add_argument("--disable-gpu")  # Deshabilitar GPU (opcional en algunos casos)
    # chrome_options.add_argument("--disable-dev-shm-usage")  # Para evitar problemas en entornos Linux
    # chrome_options.add_argument("--no-sandbox")  # Para evitar problemas de permisos en Linux
    # chrome_options.add_argument("--disable-features=NetworkService,NetworkServiceInProcess")  # Más control sobre caché

    # chrome_options.add_argument("--start-maximized")  # Abre la ventana en pantalla completa
    # # Crear la instancia del WebDriver con las opciones configuradas
    # driver = webdriver.Chrome(options=chrome_options)
    # driver.maximize_window()

    # # Move mouse with a smooth transition

    # driver.get("https://www.instagram.com/")


    # Configuración de Firefox
    firefox_options = Options()
    # firefox_options.set_preference("general.useragent.override", random_user_agent)  # Si usas user-agent aleatorio

    # firefox_options.set_preference("browser.privatebrowsing.autostart", True)  # Modo incógnito
    # firefox_options.set_preference("browser.cache.disk.enable", False)  # Desactiva caché en disco
    # firefox_options.set_preference("browser.cache.memory.enable", False)  # Desactiva caché en memoria
    # firefox_options.set_preference("browser.cache.offline.enable", False)  # Desactiva caché offline
    # firefox_options.set_preference("network.http.use-cache", False)  # Desactiva caché HTTP

    # # Deshabilita aceleración por hardware
    # firefox_options.set_preference("layers.acceleration.disabled", True)

    # # Evita problemas de memoria compartida y sandbox (no tan necesario en Firefox, pero por coherencia)
    # firefox_options.set_preference("security.sandbox.content.level", 0)

    # # Ventana maximizada
    # firefox_options.add_argument("--start-maximized")

    # Instanciar WebDriver
    driver = webdriver.Firefox(options=firefox_options)
    # driver.maximize_window()

    # Move mouse with a smooth transition
    driver.get("https://www.instagram.com/")

    pyautogui.moveTo(500, 500, duration=0.5)  # Moves in 1.5 seconds
    for _ in range(5):  # Repeat 4 times
        pyautogui.click() 
        pyautogui.scroll(-800)
        pyautogui.scroll(300)  # Scroll up by 500
        time.sleep(1)  # Short delay to mimic human behavior

    try:
        # Encuentra los campos de entrada para el nombre de usuario y la contraseña
        username_input = driver.find_element(By.CSS_SELECTOR, "input[aria-label='Teléfono, usuario o correo electrónico']")
        password_input = driver.find_element(By.XPATH, value = "//input[@aria-label='Contraseña']")

        # Ingresa tus credenciales de inicio de sesión
        username_input.send_keys("analiticadedatosbc@sedbarranquilla.edu.co")
        password_input.send_keys("Alonso1470@")

        # Envía el formulario de inicio de sesión
        password_input.send_keys(Keys.RETURN)

    except:   
         # Encuentra los campos de entrada para el nombre de usuario y la contraseña
        username_input = driver.find_element(By.CSS_SELECTOR, "input[aria-label='Número de móvil, nombre de usuario o correo electrónico']")
        password_input = driver.find_element(By.XPATH, value = "//input[@aria-label='Contraseña']")

        # Ingresa tus credenciales de inicio de sesión
        username_input.send_keys("analiticadedatosbc@sedbarranquilla.edu.co")
        password_input.send_keys("Alonso1470@")

        # Envía el formulario de inicio de sesión
        password_input.send_keys(Keys.RETURN)
    # ENTER LINK
  
    time.sleep(8)
    driver.get(url)
    
    
    ## Scroll comments container
    pyautogui.moveTo(465, 465, duration=1)
    pyautogui.click()
    

    ## Scroll comments container
    try:
        time.sleep(1)
        pyautogui.moveTo(938, 286, duration=1)
        pyautogui.click()

        for _ in range(10): #diez intento de scroll hacia abajo 
        # pyautogui.click() 
            pyautogui.scroll(-300)  # Scroll up by 500
            time.sleep(2.5)

    
    except:
        time.sleep(1)
        # Espera a que el botón sea clickeable
        boton  = driver.find_element(By.XPATH, value = "/html/body/div[5]/div[2]/div/div/div[1]/div/div[2]/div/div/div/div/div[2]/div/div[1]/div").click()                                                                
    
        
    finally:
        pass

    
# /html/body/div[5]/div[2]/div/div/div[1]/div/div[2]/div/div/div/div/div[1]/div/div 
# "div.x1lliihq.x1n2onr6.x1roi4f4"

    # pyautogui.moveTo(1250, 463, duration=0.5) 
     
    
    
    # driver.get(url)
    # time.sleep(15)    

    comentarios = driver.find_elements(By.CSS_SELECTOR,"div.x78zum5.xdt5ytf.x1iyjqo2") #CLASE DEL CONTENEDOR DE NOMBRE DE USUARIO, COMENTARIO, HORA Y REACCIONES

    # Extraer los textos de los comentarios

    textos_comentarios = [comentario.text for comentario in comentarios]
    procesados         = [modelamiento(texto) for texto in textos_comentarios]
    flattened_data = [item for sublist in procesados for item in sublist]

    # Crear un DataFrame dividiendo cada elemento en "Usuario" y "Comentario"

    df = pd.DataFrame(flattened_data, columns=["Usuario", "Comentario", "Hora", "Reacciones"])
    df["url_instagram"] = url
    # df = pd.DataFrame([comentario.split('\n', 1) for comentario in textos_comentarios], columns=['Usuario', 'Comentario'])

    # Guardar en un archivo Excel

    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    filename = f'data/data_{medio}_{timestamp}.xlsx'
    # filename = f'data_{medio}_{timestamp}.xlsx'

    df.to_excel(filename, index=False)
    print(textos_comentarios)
    driver.quit()
    print("Excel generado con éxito 🎉")

# %%
# for url in lista_url:
#     ManagerInstagramScrapper(url,medio="medios_comunicacion")

# %% [markdown]
# ### VERSION MISMA VENTANA Y CACHE / UNICO LOGIN A LA CUENTA DE INSTRAGRAM

# %%
df = pd.read_excel('url\\batch_apify_02.xlsx')

# %%
lista_url = list(df['url'])

# %%
# lista_url =  [ 



    
# ]

# %%
def ManagerInstagramScrapper(urls, medio, username, password):

    # Configuración Firefox
    firefox_options = Options()
    driver = webdriver.Firefox(options=firefox_options)
    # driver.maximize_window()

    # LOGIN UNA SOLA VEZ
    driver.get("https://www.instagram.com/")
    time.sleep(3)

    try:
        username_input = driver.find_element(By.CSS_SELECTOR, "input[aria-label='Teléfono, usuario o correo electrónico']")
        password_input = driver.find_element(By.XPATH, "//input[@aria-label='Contraseña']")
    except:
        username_input = driver.find_element(By.CSS_SELECTOR, "input[aria-label='Número de móvil, nombre de usuario o correo electrónico']")
        password_input = driver.find_element(By.XPATH, "//input[@aria-label='Contraseña']")

    username_input.send_keys(username)
    password_input.send_keys(password)
    password_input.send_keys(Keys.RETURN)
    time.sleep(8)  # Esperar login

    for url in urls:
        driver.get(url)
        time.sleep(5)

        # Scroll para mostrar comentarios
        pyautogui.moveTo(465, 465, duration=1)
        pyautogui.click()
        time.sleep(1)

        try:
            pyautogui.moveTo(938, 286, duration=1)
            pyautogui.click()
            for _ in range(10):
                pyautogui.scroll(-300)
                time.sleep(2.5)
        except:
            pass

        # Extraer comentarios

        comentarios = driver.find_elements(By.CSS_SELECTOR, "div.x78zum5.xdt5ytf.x1iyjqo2") #se necesita buscar el bloque correcto, de solo usuario y comentario
        textos_comentarios = [comentario.text for comentario in comentarios]

        # Procesar comentarios con tu función modelamiento
        # procesados = [modelamiento(texto) for texto in textos_comentarios]
        # flattened_data = [item for sublist in procesados for item in sublist]

        resultado = limpiar_comentarios_(textos_comentarios)
        

        # df = pd.DataFrame(flattened_data, columns=["Usuario", "Comentario", "Hora", "Reacciones"])
        df = pd.DataFrame(resultado, columns=["Usuario", "Comentario","Likes"]).drop_duplicates(subset=["Usuario", "Comentario"])
        
        df['Comentario'] = [x.split(' ', 2)[2] if len(x.split(' ', 2)) > 2 else '' for x in df['Comentario']]
        df["url_instagram"] = url
        
        try:
            df = df.drop(index=1)
        except:
            continue 

        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        filename = f'data/data_{medio}_{timestamp}.xlsx'
        df.to_excel(filename, index=False)

        print(f"Excel generado para {url}")
        # print(resultado)


    driver.quit()
    print("Navegador cerrado y proceso finalizado.")

    return textos_comentarios

# %%
ManagerInstagramScrapper(
    urls=lista_url,
    medio="instagram",
    username="analiticadedatosbc@sedbarranquilla.edu.co",
    password="Ariadna1228440@"
)
# Out:
# Excel generado para https://www.instagram.com/p/DKAeC_CJT23/
# Excel generado para https://www.instagram.com/p/DKCqizCNbE8/
# Excel generado para https://www.instagram.com/p/DKA25MwNjQ2/
# Excel generado para https://www.instagram.com/p/DKBLKt0usNT/
# Excel generado para https://www.instagram.com/p/DJ8AL_Nsv3l/
# Excel generado para https://www.instagram.com/p/DJ-VEiOtath/
# Excel generado para https://www.instagram.com/p/DKE-ZCZNmup/
# Excel generado para https://www.instagram.com/p/DJjvx5HtNf3/
# Excel generado para https://www.instagram.com/p/DJmb7dsM3yS/
# Excel generado para https://www.instagram.com/p/DJmzRm7S9OZ/
# Excel generado para https://www.instagram.com/p/DJPDrbeNLNz/
# Excel generado para https://www.instagram.com/p/DJpYe3WScsC/
# Excel generado para https://www.instagram.com/p/DJnPWW9scEp/
# Excel generado para https://www.instagram.com/p/DJiYTjTMBGg/
# Excel generado para https://www.instagram.com/p/DJpu48asUL5/
# Excel generado para https://www.instagram.com/p/DJotvFtoPV9/
# Excel generado para https://www.instagram.com/p/DJm0eDUJJBL/
# Excel generado para https://www.instagram.com/p/DJpE7pXN488/
# Excel generado para https://www.instagram.com/p/DJnITTZpmvM/
# Excel generado para https://www.instagram.com/p/DJkkTTgStlu/
# Excel generado para https://www.instagram.com/p/DJj-1y0pNsK/
# Excel generado para https://www.instagram.com/p/DJiQkrJS9WC/
# Excel generado para https://www.instagram.com/p/DJh8H01pX9h/
# Excel generado para https://www.instagram.com/p/DJk1IkXJKnG/
# Excel generado para https://www.instagram.com/p/DJmdi-TSKc2/
# Excel generado para https://www.instagram.com/p/DJkSRHzJum-/
# Excel generado para https://www.instagram.com/p/DJ7KnucOY2W/
# Excel generado para https://www.instagram.com/p/DJ4FPsAun-1/
# Excel generado para https://www.instagram.com/p/DJ3DNvEO1gx/
# Excel generado para https://www.instagram.com/p/DJ4j2yOOTUA/
# Excel generado para https://www.instagram.com/p/DJejGecS7tx/
# Excel generado para https://www.instagram.com/p/DJW_Yo_t0gg/
# Excel generado para https://www.instagram.com/p/DKKJSpYtleP/
# Excel generado para https://www.instagram.com/p/DJKwN3Byn5Z/
# Excel generado para https://www.instagram.com/p/DJUv9_UynMn/
# Excel generado para https://www.instagram.com/p/DJKHvJku7e3/
# Excel generado para https://www.instagram.com/p/DJhfE3vxHR6/
# Excel generado para https://www.instagram.com/p/DJfqOssR4Du/
# Excel generado para https://www.instagram.com/p/DKE-bi5t5ce/
# Excel generado para https://www.instagram.com/p/DJMpjzTpme4/
# Excel generado para https://www.instagram.com/p/DJJ-z5kS2EG/
# Excel generado para https://www.instagram.com/p/DJXM_vExxLD/
# Excel generado para https://www.instagram.com/p/DJageWDRJy1/
# Excel generado para https://www.instagram.com/p/DJXviMgPyXt/
# Excel generado para https://www.instagram.com/p/DJ7_en_M3QY/
# Excel generado para https://www.instagram.com/p/DJXqifxvYS4/
# Excel generado para https://www.instagram.com/p/DJcNUS9Rzzl/
# Excel generado para https://www.instagram.com/p/DJcAP2hxxI3/
# Excel generado para https://www.instagram.com/p/DJUPs3at3Q9/
# Excel generado para https://www.instagram.com/p/DJiGa7QuWXz/
# Excel generado para https://www.instagram.com/p/DJXvrSMx3xY/
# Excel generado para https://www.instagram.com/p/DJiQgD5xXTd/
# Excel generado para https://www.instagram.com/p/DJet4ppOFiF/
# Excel generado para https://www.instagram.com/p/DJXAFG_MUSt/
# Excel generado para https://www.instagram.com/p/DJQIPVAM94z/
# Excel generado para https://www.instagram.com/p/DJUgNU9uZOr/
# Excel generado para https://www.instagram.com/p/DJS2rIVu117/
# Excel generado para https://www.instagram.com/p/DJOx0yHvWAY/
# Excel generado para https://www.instagram.com/p/DJKWyVZuiG5/
# Excel generado para https://www.instagram.com/p/DJlCIH8OGpp/
# Excel generado para https://www.instagram.com/p/DJIbShONA-G/
# Excel generado para https://www.instagram.com/p/DJMnGlOuPuU/
# Excel generado para https://www.instagram.com/p/DJIiVYeuRl3/
# Excel generado para https://www.instagram.com/p/DJkinFXtOuW/
# Excel generado para https://www.instagram.com/p/DJhaBQsJFBW/
# Excel generado para https://www.instagram.com/p/DJg-Ac7txn1/
# Excel generado para https://www.instagram.com/p/DJfO-cMyYwG/
# Excel generado para https://www.instagram.com/p/DJrh-TVNZbs/
# Excel generado para https://www.instagram.com/p/DJb4fvTyX_r/
# Excel generado para https://www.instagram.com/p/DJkdICpRyTz/
# Excel generado para https://www.instagram.com/p/DJ5OsAUyuap/
# Excel generado para https://www.instagram.com/p/DJe-FhduO-5/
# Excel generado para https://www.instagram.com/p/DJILy3Hy52w/
# Excel generado para https://www.instagram.com/p/DJnIb7XNA1h/
# Excel generado para https://www.instagram.com/p/DJKXFfcSSDR/
# Excel generado para https://www.instagram.com/p/DJpjonryqQC/
# Excel generado para https://www.instagram.com/p/DJjeh8IyPac/
# Excel generado para https://www.instagram.com/p/DJj6n9NO2rg/
#  'erikasilvaurbano\n 4 sem\nConocimos a Jeannette Jara Román en la calle. Estábamos en un stand exponiendo en una actividad de la Universidad de Chile que queda cerca del Ministerio del Trabajo y Previsión Social. Ella iba caminando a su oficina y pasó a ver lo que hacíamos. Le preguntamos cómo hacía para tener tanta paciencia para negociar con el empresariado y ella nos dijo que no era fácil, pero que la pega era sacar el mejor acuerdo posible para beneficiar a los trabajadores.\nUna vez por trabajo, conocí a su hermano que es periodista. Jeannette trabajaba en ese tiempo como subsecretaría de Previsión Social, pero no era conocida. Él me contó que eran de El Cortijo, una población de gente de esfuerzo de la comuna de Conchalí.\nPocas veces gente del barrio de Jeannette y de comunas sencillas llega a ocupar puestos de alta responsabilidad y eso me hizo no olvidar ese nombre.\nYo no soy comunista, pero admiro su trayectoria. La gente que no ha trabajado en el poder ni siquiera imagina lo que se lucha para sacar adelante lo que uno cree que es justo. Es muy fácil decir " yo lo habría hecho así y sería mejor el resultado", pero otra cosa es con guitarra porque gobernar sin mayoría, obliga siempre a negociar.\nGaleano dice "los científicos dicen que estamos hechos de átomos, pero a mí un pajarito me contó que estamos hechos de historia ". La historia de Jeannette es bonita. La historia de Jeannette llenaría de esperanza a miles de niños y niñas que viven en barrios sencillos, porque si ella pudo llegar al poder, ellos y ellas también podrían.\nLa esperanza es una enfermedad incurable para mí, cada vez que la pierdo, la vuelvo a contraer. Jeannette da esperanza en tiempos hostiles. Su sencillez, talento, fortaleza y dulzura, hace pensar que otro mundo puede ser posible.\n5 Me gusta\nResponder',
#  'pc.nuble\n 4 sem\nJara junto a los trabajadores ❤️🙌\n1 Me gusta\nResponder',
#  'elenaitaca\n 4 sem\nJara; hay trabajo toda su vida; viene de familia SIN PRIVILEGIOS; esta es una oportunidad para la clase trabajadora. Yo voto por JARA!!!\n3 Me gusta\nResponder',
#  'jimenagarate\n 4 sem\nYo voto #jara\n3 Me gusta\nResponder',
#  'jazf1964\n 3 sem\nNo me representa ella ni el comunismo\n1 Me gusta\nResponder',
#  'plateropino\n 4 sem\nHay q estar bien pitiao para creer en el comunismo😂😂😂😂\n3 Me gusta\nResponder',
#  'lion.215121\n 4 sem\nVAMOS A VOTAR POR JEANETTE JARA !!!\n2 Me gusta\nResponder',
#  'pato_guerram\n 4 sem\nDeja de hablar de lucha!! Después andas lloriqueando. Zurdos pencas\n1 Me gusta\nResponder',
#  '3281 Me gusta']

# %% [markdown]
# ___

# %%
# LIMPIEZA DATAFRAME Y CONSOLIDADO DIARIO
# ruta_directorio = "/data/data final"
# ruta_archivo = os.path.join(ruta_directorio, "archivo_unido.xlsx")

carpeta = 'data'

archivos = [f for f in os.listdir(carpeta) if f.endswith((".xlsx",".xls"))]
dataframes = []

for archivo in archivos:
    ruta_completa = os.path.join(carpeta,archivo)
    df = pd.read_excel(ruta_completa)
    dataframes.append(df)

df_final = pd.concat(dataframes,ignore_index=True)

# %%
df_final.to_excel('data consolidado/batch_02_comentarios.xlsx',index=False)
