# %%
#MODULOS DE SELENIUM
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.options import Options

from selenium.webdriver.firefox.options import Options
from selenium.webdriver.firefox.service import Service



from datetime import datetime

#MODULOS SECUNDARIOS
import pandas as pd
import numpy as np
import pyautogui
import os
import time
import ssl
import sys
import traceback
import re

#MODULO ALERTAS DESACTIVADAS
import warnings
warnings.filterwarnings('ignore')

#MODULO PROPIOS
from utils import modelamiento,limpiar_comentarios_

# %%
# try:
#     # Obtener tamaño del monitor
#     ancho, alto = pyautogui.size()

#     while True:
#         # Posición actual del cursor
#         x, y = pyautogui.position()

#         # Cálculo proporcional
#         porcentaje_x = x / ancho
#         porcentaje_y = y / alto

#         print(
#             f"Posición: X={x}, Y={y} | "
#             f"Relativo: X={porcentaje_x:.2%}, Y={porcentaje_y:.2%}",
#             end="\r"
#         )

#         time.sleep(0.1)

# except KeyboardInterrupt:
#     print("\nDetenido por el usuario.")

# %%
# lista_url = [
#     "https://www.instagram.com/reel/DJFlmTks4bv/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA===",
#     "https://www.instagram.com/reel/DJFjzGSPmoW/?igsh=bTI2bzM4NWJrczdh",
#     "https://www.instagram.com/p/DJFFVOUB8VC/?igsh=Ym5razRxaGFmeHo=",
#     "https://www.instagram.com/p/DJE80WwpfSA/?igsh=cmE4Zm96czhhNTE0",
#     "https://www.instagram.com/reel/DJEztf8vb7r/?igsh=MWdmajQwMDUyMnR4cQ==",
#     "https://www.instagram.com/p/DJE-wEvRJPN/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA==",
#     "https://www.instagram.com/p/DJEgnaYtcst/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA==",
#     "https://www.instagram.com/reel/DJEuTRSt_m1/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA==",
#     "https://www.instagram.com/reel/DJFY8RdNlVe/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA==",
#     "https://www.instagram.com/reel/DJDa4C-C6-S/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA==",
#     "https://www.instagram.com/p/DJFFIA9xIu5/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA=="
# ]

# %% [markdown]
# ### VERSION VENTANAS DIFERENTES

# %%
def ManagerInstagramScrapper_version (url,medio):

    # # Configuracion Chrome
    # chrome_options = Options()
    # # chrome_options.add_argument(f"--user-agent={random_user_agent}")
    # chrome_options.add_argument("--incognito")  # Modo incógnito
    # chrome_options.add_argument("--disable-cache")  # Deshabilitar la caché
    # chrome_options.add_argument("--disable-application-cache")  # Deshabilitar caché de aplicaciones
    # chrome_options.add_argument("--disable-gpu")  # Deshabilitar GPU (opcional en algunos casos)
    # chrome_options.add_argument("--disable-dev-shm-usage")  # Para evitar problemas en entornos Linux
    # chrome_options.add_argument("--no-sandbox")  # Para evitar problemas de permisos en Linux
    # chrome_options.add_argument("--disable-features=NetworkService,NetworkServiceInProcess")  # Más control sobre caché

    # chrome_options.add_argument("--start-maximized")  # Abre la ventana en pantalla completa
    # # Crear la instancia del WebDriver con las opciones configuradas
    # driver = webdriver.Chrome(options=chrome_options)
    # driver.maximize_window()

    # # Move mouse with a smooth transition

    # driver.get("https://www.instagram.com/")


    # Configuración de Firefox
    firefox_options = Options()
    # firefox_options.set_preference("general.useragent.override", random_user_agent)  # Si usas user-agent aleatorio

    # firefox_options.set_preference("browser.privatebrowsing.autostart", True)  # Modo incógnito
    # firefox_options.set_preference("browser.cache.disk.enable", False)  # Desactiva caché en disco
    # firefox_options.set_preference("browser.cache.memory.enable", False)  # Desactiva caché en memoria
    # firefox_options.set_preference("browser.cache.offline.enable", False)  # Desactiva caché offline
    # firefox_options.set_preference("network.http.use-cache", False)  # Desactiva caché HTTP

    # # Deshabilita aceleración por hardware
    # firefox_options.set_preference("layers.acceleration.disabled", True)

    # # Evita problemas de memoria compartida y sandbox (no tan necesario en Firefox, pero por coherencia)
    # firefox_options.set_preference("security.sandbox.content.level", 0)

    # # Ventana maximizada
    # firefox_options.add_argument("--start-maximized")

    # Instanciar WebDriver
    driver = webdriver.Firefox(options=firefox_options)
    # driver.maximize_window()

    # Move mouse with a smooth transition
    driver.get("https://www.instagram.com/")

    pyautogui.moveTo(500, 500, duration=0.5)  # Moves in 1.5 seconds
    for _ in range(5):  # Repeat 4 times
        pyautogui.click() 
        pyautogui.scroll(-800)
        pyautogui.scroll(300)  # Scroll up by 500
        time.sleep(1)  # Short delay to mimic human behavior

    try:
        # Encuentra los campos de entrada para el nombre de usuario y la contraseña
        username_input = driver.find_element(By.CSS_SELECTOR, "input[aria-label='Teléfono, usuario o correo electrónico']")
        password_input = driver.find_element(By.XPATH, value = "//input[@aria-label='Contraseña']")

        # Ingresa tus credenciales de inicio de sesión
        username_input.send_keys("analiticadedatosbc@sedbarranquilla.edu.co")
        password_input.send_keys("Alonso1470@")

        # Envía el formulario de inicio de sesión
        password_input.send_keys(Keys.RETURN)

    except:   
         # Encuentra los campos de entrada para el nombre de usuario y la contraseña
        username_input = driver.find_element(By.CSS_SELECTOR, "input[aria-label='Número de móvil, nombre de usuario o correo electrónico']")
        password_input = driver.find_element(By.XPATH, value = "//input[@aria-label='Contraseña']")

        # Ingresa tus credenciales de inicio de sesión
        username_input.send_keys("analiticadedatosbc@sedbarranquilla.edu.co")
        password_input.send_keys("Alonso1470@")

        # Envía el formulario de inicio de sesión
        password_input.send_keys(Keys.RETURN)
    # ENTER LINK
  
    time.sleep(8)
    driver.get(url)
    
    
    ## Scroll comments container
    pyautogui.moveTo(465, 465, duration=1)
    pyautogui.click()
    

    ## Scroll comments container
    try:
        time.sleep(1)
        pyautogui.moveTo(938, 286, duration=1)
        pyautogui.click()

        for _ in range(10): #diez intento de scroll hacia abajo 
        # pyautogui.click() 
            pyautogui.scroll(-300)  # Scroll up by 500
            time.sleep(2.5)

    
    except:
        time.sleep(1)
        # Espera a que el botón sea clickeable
        boton  = driver.find_element(By.XPATH, value = "/html/body/div[5]/div[2]/div/div/div[1]/div/div[2]/div/div/div/div/div[2]/div/div[1]/div").click()                                                                
    
        
    finally:
        pass

    
# /html/body/div[5]/div[2]/div/div/div[1]/div/div[2]/div/div/div/div/div[1]/div/div 
# "div.x1lliihq.x1n2onr6.x1roi4f4"

    # pyautogui.moveTo(1250, 463, duration=0.5) 
     
    
    
    # driver.get(url)
    # time.sleep(15)    

    comentarios = driver.find_elements(By.CSS_SELECTOR,"div.x78zum5.xdt5ytf.x1iyjqo2") #CLASE DEL CONTENEDOR DE NOMBRE DE USUARIO, COMENTARIO, HORA Y REACCIONES

    # Extraer los textos de los comentarios

    textos_comentarios = [comentario.text for comentario in comentarios]
    procesados         = [modelamiento(texto) for texto in textos_comentarios]
    flattened_data = [item for sublist in procesados for item in sublist]

    # Crear un DataFrame dividiendo cada elemento en "Usuario" y "Comentario"

    df = pd.DataFrame(flattened_data, columns=["Usuario", "Comentario", "Hora", "Reacciones"])
    df["url_instagram"] = url
    # df = pd.DataFrame([comentario.split('\n', 1) for comentario in textos_comentarios], columns=['Usuario', 'Comentario'])

    # Guardar en un archivo Excel

    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    filename = f'data/data_{medio}_{timestamp}.xlsx'
    # filename = f'data_{medio}_{timestamp}.xlsx'

    df.to_excel(filename, index=False)
    print(textos_comentarios)
    driver.quit()
    print("Excel generado con éxito 🎉")

# %%
# for url in lista_url:
#     ManagerInstagramScrapper(url,medio="medios_comunicacion")

# %% [markdown]
# ### VERSION MISMA VENTANA Y CACHE / UNICO LOGIN A LA CUENTA DE INSTRAGRAM

# %%
# df = pd.read_excel('url\\batch_apify_02.xlsx')

# %%
# lista_url = list(df['url'])

# %%
lista_url =  [ 

'https://www.instagram.com/reel/DKyJSkPtAs1/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA==' ,
'https://www.instagram.com/reel/DKyKbQFNZHV/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA==' ,
'https://www.instagram.com/reel/DKyGjIRtf2b/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA=='

]

# %%
def ManagerInstagramScrapper(urls, medio, username, password):

    # Configuración Firefox
    firefox_options = Options()
    driver = webdriver.Firefox(options=firefox_options)
    # driver.maximize_window()

    # LOGIN UNA SOLA VEZ
    driver.get("https://www.instagram.com/")
    time.sleep(3)

    try:
        username_input = driver.find_element(By.CSS_SELECTOR, "input[aria-label='Teléfono, usuario o correo electrónico']")
        password_input = driver.find_element(By.XPATH, "//input[@aria-label='Contraseña']")
    except:
        username_input = driver.find_element(By.CSS_SELECTOR, "input[aria-label='Número de móvil, nombre de usuario o correo electrónico']")
        password_input = driver.find_element(By.XPATH, "//input[@aria-label='Contraseña']")

    username_input.send_keys(username)
    password_input.send_keys(password)
    password_input.send_keys(Keys.RETURN)
    time.sleep(8)  # Esperar login

    for url in urls:
        driver.get(url)
        time.sleep(5)

        # Scroll para mostrar comentarios
        pyautogui.moveTo(465, 465, duration=1)
        pyautogui.click()
        time.sleep(1)

        try:
            pyautogui.moveTo(938, 286, duration=1)
            pyautogui.click()
            for _ in range(50): #NUMERO DE SCROLLS
                pyautogui.scroll(-300)
                time.sleep(3) #TIEMPO DE ESPERA SCROLL
        except:
            pass

        # Extraer comentarios

        comentarios = driver.find_elements(By.CSS_SELECTOR, "div.x78zum5.xdt5ytf.x1iyjqo2") #se necesita buscar el bloque correcto, de solo usuario y comentario
        textos_comentarios = [comentario.text for comentario in comentarios]

        # Procesar comentarios con tu función modelamiento
        # procesados = [modelamiento(texto) for texto in textos_comentarios]
        # flattened_data = [item for sublist in procesados for item in sublist]

        resultado = limpiar_comentarios_(textos_comentarios)
        

        # df = pd.DataFrame(flattened_data, columns=["Usuario", "Comentario", "Hora", "Reacciones"])
        df = pd.DataFrame(resultado, columns=["Usuario", "Comentario","Likes"]).drop_duplicates(subset=["Usuario", "Comentario"])
        
        df['Comentario'] = [x.split(' ', 2)[2] if len(x.split(' ', 2)) > 2 else '' for x in df['Comentario']]
        df["url_instagram"] = url
        
        try:
            df = df.drop(index=1)
        except:
            continue 

        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        filename = f'data/data_{medio}_{timestamp}.xlsx'
        df.to_excel(filename, index=False)

        print(f"Excel generado para {url}")
        # print(resultado)


    driver.quit()
    print("Navegador cerrado y proceso finalizado.")

    return textos_comentarios

# %%
ManagerInstagramScrapper(
    urls=lista_url,
    medio="instagram",
    username="analiticadedatosbc@sedbarranquilla.edu.co",
    password="Ariadna1228440@"
)
# Out:
# Excel generado para https://www.instagram.com/reel/DKyJSkPtAs1/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA==
# Excel generado para https://www.instagram.com/reel/DKyKbQFNZHV/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA==
# Excel generado para https://www.instagram.com/reel/DKyGjIRtf2b/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA==
# Navegador cerrado y proceso finalizado.
# ['prensachilena\n 1 día\n¿Le darás tu voto? 🗳️ \n\nLa franja electoral de Jeannette Jara para las primarias presidenciales del oficialísimo.',
#  'iyaakako\n 1 día\nT AMO JEANETTE\n104 Me gusta\nResponder\nanahi.paillalef\n 1 día\nLa mejor ministra del trabajo que hemos tenido! Las 40 horas, aumento de sueldo, ley Karin. Creo en UD #jeanetjarapresidenta desde Conchali para Todo Chile\n1331 Me gusta\nResponder\nVer las 31 respuestas\nisidoraestefania.vi\n 1 día\nEstaban súper contentos con el aumento de salario mínimo y las 40 horas , saben quien impulsó esos proyectos ? La ministra del trabajo Jeannette Jara\n5939 Me gusta\nResponder\nVer las 121 respuestas\nkaritohb\n 1 día\nYo voto Jara 💜\n48 Me gusta\nResponder\narude1986\n 1 día\n👏👏👏\n2 Me gusta\nResponder\noscuraluna111\n 1 día\nMI PRESIDENTA❤️\n864 Me gusta\nResponder\nVer las 10 respuestas\nuna_demencia\n 1 día\nAguante mi presi\n418 Me gusta\nResponder\nVer las 1 respuestas\nmajogvv\n 1 día\nla presidenta de las girlsss 😚\n5047 Me gusta\nResponder\nVer las 95 respuestas\ngabyvidal_21\n 1 día\nJARA PRESIDENTA !! ❤️🙌🔥👏\n57 Me gusta\nResponder\n_cristinaveronica_\n 19 h\nYo no vengo a prometer, yo ya hice 🔥 ❤️🇨🇱\n9 Me gusta\nResponder\ncamitamilas\n 1 día\nMi presiiii, a triunfar ✊🏻♥️\n153 Me gusta\nResponder\nVer las 3 respuestas\ntamaratorreshuechucura\n 1 día\nSiiii obvio que si ✌️\n6 Me gusta\
#  'ma.uricio2761\n 1 día\nJannette Jara es la candidata más preparada para los problemas actuales, ella va a dar solución, los demás son los mismos oportunistas de siempre.\n6 Me gusta\nResponder',
#  'magentaa1\n 1 día\nvamos vamos Jara ❤️\n3 Me gusta\nResponder',
#  'ysolodespeguemispies\n 1 día\nmi presidenta <3\n3 Me gusta\nResponder',
#  'vivipazmart\n 1 día\nVoy más que por color politico! Voy por la verdad ❤️\n4 Me gusta\nResponder',
#  'dora_mendez_lobos\n 1 día\nSiiiiiiiii!!!?????👏👏👏👏👏👏🇨🇱✊💜🇨🇱🇨🇱\n4 Me gusta\nResponder',
#  'jjcc.regionalponiente\n 1 día\n#jeannettejarapresidenta\n12 Me gusta\nResponder\nVer traducción',
#  'celyn_valeska.ml\n 1 día\nJara ❤️\n9 Me gusta\nResponder',
#  'alej.molina\n 21 h\nMi votos; más el de mi señora; más el de mis 2 hijos\n7 Me gusta\nResponder',
#  'profe_danzarina\n 1 día\nViajo a mi ciudad solo para votar por ti en las primarias ❤️\n748 Me gusta\nResponder',
#  'silvamallega\n 1 día\nobvio ,mi voto es para jara 💪💪💪💪\n7 Me gusta\nResponder',
#  'ignacia_javi_\n 1 día\nVamossss mi futura presi🫶🏻\n3 Me gusta\nResponder',
#  'liviagv__\n 1 día\nMi candidata, mi Presidenta ❤️\n1 Me gusta\nResponder',
#  'jachinho\n 1 día\nHagamos un ejercicio patriota y votemos por el apellido más chileno 🇨🇱🇨🇱: JARAAA\n13 Me gusta\nResponder',
#  'asq_zada\n 20 h\nYo voto Jeanette Jara 👍\n1 Me gusta\nResponder',
#  'francis.c.lagos\n 20 h\nPuros bots jajajaaj\n1 Me gusta\nResponder',
#  'benjx.roa\n 1 día\nBoric evolucionó en mujer 😂\n95 Me gusta\nResponder',
#  'joel.foster67\n 1 día\nNo queremos más MARXISTAS\n104 Me gusta\nResponder',
#  'magdalenacofre\n 1 día\nKAST ❤️\n413 Me gusta\nResponder',
#  'listeilor_ventas\n 13 h\nLa delincuencia, corrupción, etc tiene un país tan lindo 🇨🇱 destruido ..\n3 Me gusta\nResponder',
#  'psych.void\n 1 día\nTiene tanto dato y sabe hablar de pana que hasta un facho pobre se culturiza\n73 Me gusta\nResponder',
#  'suyiinn\n 1 día\nPucha que me gusta la tía jara\n6 Me gusta\nResponder',
#  'f794ssss\n 1 día\nLey 40 hrs pa los flojos, ley Karin pa los cristales (está saturado de denuncias y las de verdad no las pueden fiscalizar como corresponde) , aumento de sueldo (todo aumento y no los 30 pesos que por eso casi queman medio chile)\n2 Me gusta\nResponder',
#  'alex.torrente.5\n 1 día\nDerecha nefasta, no le hace bien a chile\n3 Me gusta\nResponder',
#  'viqui.2022\n 1 día\nY quién le importa esta zurda\nResponder',
#  'astrobsez\n 1 día\nMe importa un champiñón, voto por quien está capacitado, por quien tiene historia en el gobierno de quien sea, por quien demostró hacer algo y por quien hizo su trabajo. VAMOS JEANETTE KTM!!! 🙌😝😝\n6 Me gusta\nResponder',
#  'espiritureciclador\n 11 h\nPOR SUPUESTO!!! JARA PRESIDENTA ❤️\n3 Me gusta\nResponder',
#  'ixchel_moonlight\n 1 día\nPiensen con estrategia... si no quieren q gane la derecha no voten por jara :( el país no la va a elegir como mayoría solo x ser del pc\n3 Me gusta\nResponder',
#  'liliana_farah1\n 6 h\nKayser\n1 Me gusta\nResponder',
#  'unamamaprofe\n 1 día\nElla es ♥️\n14 Me gusta\nResponder',
#  'chavez_achc\n 1 día\n🔥🔥\n4 Me gusta\nResponder',
#  "amatista__confecciones\n 12 h\nHemos sido tan engañados que alguien nos promete no mentiré como promesa de campaña :'(\n1 Me gusta\nResponder",
#  'ayelenbarria\n 1 día\nJara = Bachelet\n8 Me gusta\nResponder',
#  'sofiasagredoo\n 1 día\nNo\n26 Me gusta\nResponder',
#  'n4.taa\n 19 h\nPor fin habria alguien que sabe del funcionamiento tecnico de la política😍\n4 Me gusta\nResponder',
#  'popularydisidente\n 1 día\nDa confianza Jara Presidenta 💕\n7 Me gusta\nResponder',
#  'rayenn.n05\n 1 día\nq no te mientan en la cara . vota jara\n6 Me gusta\nResponder',
#  '_daniela.paz__\n 1 día\n👏🏻👏🏻👏🏻\n2 Me gusta\nResponder',
#  'matiastl\n 1 día\n❤️❤️❤️❤️\n4 Me gusta\nResponder',
#  'wxnkv\n 1 día\npresidenta🚩\n8 Me gusta\nResponder',
#  'paulaperez.concejala\n 1 día\nUna real ✨\n5 Me gusta\nResponder',
#  '_.g4briel4.__\n 1 día\nMi Presiii ✊❤️\n15 Me gusta\nResponder',
#  'moncada_pancho\n 1 día\nSi!! 🙌\n9 Me gusta\nResponder',
#  'chan.schulz\n 1 día\nMi voto\n10 Me gusta\nResponder',
#  'yeser.ss\n 1 día\nSoporten que será la ganadora 💕\n5 Me gusta\nResponder',
#  'michi_morenoz\n 1 día\nMi presi ❤️\n14 Me gusta\nResponder',
#  'florrdelotx\n 1 día\nMi candidata 😍\n4 Me gusta\nResponder',
#  'christiann_luna\n 23 h\nMi futura presidenta 😍\n4 Me gusta\nResponder',
#  'porotojate\n 1 día\n😂😂😂 y los scws le dan el voto....Cuba democracia 😂😂😂😂😂\n13 Me gusta\nResponder',
#  'joselo_fernandz\n 1 día\nGana 8 millones y la vende que es del pueblo\n64 Me gusta\nResponder',
#  'mariajose_ibau\n 1 día\nMi candidata ❤️\n24 Me gusta\nResponder',
#  'panxitoftfran\n 1 día\nLa única que sabe de pobreza\n7 Me gusta\nResponder',
#  'aviolettabella\n 1 día\nLa sra Yanet Jara.lucho hasta sacar adelante todo lo que le pidieron.en su trabajo.\n6 Me gusta\nResponder',
#  'soyunachicalunar\n 1 día\nElla es excelente, peor es mala carta para una segunda vuelta en un país anticomunista\n1 Me gusta\nResponder',
#  'danlovvv\n 1 día\nTodo el rato por Jara🙌❤️\n7 Me gusta\nResponder',
#  'bikerzx3r\n 22 h\nVoy por Winter, por qué se que ella pasará a primera 💪🏻 en primera vamos con todo❤️❤️❤️❤️\n1 Me gusta\nResponder',
#  'sandovalg_____\n 1 día\nLes guste o no ganara!!!\n19 Me gusta\nResponder',
#  'chechygata\n 1 día\n😍😍😍😍😍🙌\nResponder',
#  'javierlifee\nResponder\nVer traducción',
#  'blackshoees_\n 1 día\n👏👏👏👏❤️❤️❤️ vamos mi futura presidenta !\nResponder',
#  'megaptera.felina\n 1 día\n😍\nResponder',
#  'elydelk\n 1 día\n✌️\nResponder',
#  'fran_cisca98\n 1 día\nJara presidenta 🙌❤️\nResponder',
#  'nickole.23\n 1 día\n😂nooooo q atroz\nResponder',
#  '_jancamil\n 1 día\nMi presidenta ❤️❤️❤️\nResponder',
#  'i.lumi_\n 1 día\nMEO KSKDKSKFJS\nResponder',
#  'yohana_skrt\n 1 día\nNoooi\nResponder',
#  'leonpiantao\n 1 día\nObvio que si 👏\nResponder',
#  'nico_eqlhbr\n 1 día\nMe encanta ella pero voy por @gonzalo.winter 👏🏻\nResponder',
#  'mono_fenixx\n 1 día\n🤢🤢🤢🤮🤮🤮🤮🤮🤮\n1 Me gusta\nResponder',
#  'lacha_ycomunacha\n 1 día\nEs bonito prometer ideales, lo difícil es hacer la pega, agarrar la pala y tener cosas para mostrar y no solo para imaginar. Jara mi presidenta\n4 Me gusta\nResponder',
#  'daniel_lizana_r\n 1 día\nLa ministra del desempleo\n1 Me gusta\nResponder',
#  'ariskagataa\n 1 día\nSi una mujer me dice q no va a mentir, yo le creo reina💅🏼✨\n2 Me gusta\nResponder',
#  'iruminot\n 1 día\n😂😂😂😂😂😂\nResponder',
#  'a.nxis\n 1 día\nVAMOS MI PRESI♥️\n2 Me gusta\nResponder',
#  'auto.departamental\n 1 día\nkast para avanzar ❤️🙌\n2 Me gusta\nResponder',
#  'kote_peralta\n 1 día\nEs la que más me tinca\nResponder',
#  'patricio.m.romano\n 1 día\nNica\nResponder',
#  'maury777_t\n 1 día\nObvio\n1 Me gusta\nResponder',
#  'reino_propiedades\n 1 día\nKast 🤝🇨🇱, les aviso que la izquierda esta gobernando,\nResponder',
#  'vngsrock\n 1 día\nNOOOOOO! 🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮\n2 Me gusta\nResponder',
#  'gi_verav\n 1 día\nSi\nResponder',
#  'sebastian__aguilar__\n 1 día\n🤡\nResponder',
#  'j_c4562\n 1 día\nNooo\nResponder',
#  '_pamesilva_\n 1 día\n❤️\n1 Me gusta\nResponder',
#  'mr.yevenes\n 1 día\nKÁISER ! Nacional libertario! Principios claros que nos liberarán del marxismo totalitario y colectivista.\nDefensa de la vida, del individuo y la propiedad privada ! Volver a la senda del crecimiento económico !\n1 Me gusta\nResponder',
#  '35 073 Me gusta']

# %% [markdown]
# ___

# %%
# LIMPIEZA DATAFRAME Y CONSOLIDADO DIARIO
# ruta_directorio = "/data/data final"
# ruta_archivo = os.path.join(ruta_directorio, "archivo_unido.xlsx")

carpeta = 'data'

archivos = [f for f in os.listdir(carpeta) if f.endswith((".xlsx",".xls"))]
dataframes = []

for archivo in archivos:
    ruta_completa = os.path.join(carpeta,archivo)
    df = pd.read_excel(ruta_completa)
    dataframes.append(df)

df_final = pd.concat(dataframes,ignore_index=True)

# %%
df_final.to_excel('data consolidado/130625_instagram_comentarios.xlsx',index=False)
