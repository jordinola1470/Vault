# %%
#MODULOS DE SELENIUM
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.options import Options

from selenium.webdriver.firefox.options import Options
from selenium.webdriver.firefox.service import Service



from datetime import datetime

#MODULOS SECUNDARIOS
import pandas as pd
import numpy as np
import pyautogui
import os
import time
import ssl
import sys
import traceback

#MODULO ALERTAS DESACTIVADAS
import warnings
warnings.filterwarnings('ignore')

#MODULO PROPIOS
from utils import modelamiento,extraer_comentarios_desde_lista

# %%
# firefox_options = Options()
# driver = webdriver.Firefox(options=firefox_options)
# # driver.maximize_window()

# # LOGIN UNA SOLA VEZ
# driver.get("https://www.instagram.com/p/DJFFIA9xIu5/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA==")

# %%
# try:
#     # Obtener tamaño del monitor
#     ancho, alto = pyautogui.size()

#     while True:
#         # Posición actual del cursor
#         x, y = pyautogui.position()

#         # Cálculo proporcional
#         porcentaje_x = x / ancho
#         porcentaje_y = y / alto

#         print(
#             f"Posición: X={x}, Y={y} | "
#             f"Relativo: X={porcentaje_x:.2%}, Y={porcentaje_y:.2%}",
#             end="\r"
#         )

#         time.sleep(0.1)

# except KeyboardInterrupt:
#     print("\nDetenido por el usuario.")

# %% [markdown]
# ### VERSION VENTANAS DIFERENTES

# %%
def ManagerInstagramScrapper_version (url,medio):

    # # Configuracion Chrome
    # chrome_options = Options()
    # # chrome_options.add_argument(f"--user-agent={random_user_agent}")
    # chrome_options.add_argument("--incognito")  # Modo incógnito
    # chrome_options.add_argument("--disable-cache")  # Deshabilitar la caché
    # chrome_options.add_argument("--disable-application-cache")  # Deshabilitar caché de aplicaciones
    # chrome_options.add_argument("--disable-gpu")  # Deshabilitar GPU (opcional en algunos casos)
    # chrome_options.add_argument("--disable-dev-shm-usage")  # Para evitar problemas en entornos Linux
    # chrome_options.add_argument("--no-sandbox")  # Para evitar problemas de permisos en Linux
    # chrome_options.add_argument("--disable-features=NetworkService,NetworkServiceInProcess")  # Más control sobre caché

    # chrome_options.add_argument("--start-maximized")  # Abre la ventana en pantalla completa
    # # Crear la instancia del WebDriver con las opciones configuradas
    # driver = webdriver.Chrome(options=chrome_options)
    # driver.maximize_window()

    # # Move mouse with a smooth transition

    # driver.get("https://www.instagram.com/")


    # Configuración de Firefox
    firefox_options = Options()
    # firefox_options.set_preference("general.useragent.override", random_user_agent)  # Si usas user-agent aleatorio

    # firefox_options.set_preference("browser.privatebrowsing.autostart", True)  # Modo incógnito
    # firefox_options.set_preference("browser.cache.disk.enable", False)  # Desactiva caché en disco
    # firefox_options.set_preference("browser.cache.memory.enable", False)  # Desactiva caché en memoria
    # firefox_options.set_preference("browser.cache.offline.enable", False)  # Desactiva caché offline
    # firefox_options.set_preference("network.http.use-cache", False)  # Desactiva caché HTTP

    # # Deshabilita aceleración por hardware
    # firefox_options.set_preference("layers.acceleration.disabled", True)

    # # Evita problemas de memoria compartida y sandbox (no tan necesario en Firefox, pero por coherencia)
    # firefox_options.set_preference("security.sandbox.content.level", 0)

    # # Ventana maximizada
    # firefox_options.add_argument("--start-maximized")

    # Instanciar WebDriver
    driver = webdriver.Firefox(options=firefox_options)
    # driver.maximize_window()

    # Move mouse with a smooth transition
    driver.get("https://www.instagram.com/")

    pyautogui.moveTo(500, 500, duration=0.5)  # Moves in 1.5 seconds
    for _ in range(5):  # Repeat 4 times
        pyautogui.click() 
        pyautogui.scroll(-800)
        pyautogui.scroll(300)  # Scroll up by 500
        time.sleep(1)  # Short delay to mimic human behavior

    try:
        # Encuentra los campos de entrada para el nombre de usuario y la contraseña
        username_input = driver.find_element(By.CSS_SELECTOR, "input[aria-label='Teléfono, usuario o correo electrónico']")
        password_input = driver.find_element(By.XPATH, value = "//input[@aria-label='Contraseña']")

        # Ingresa tus credenciales de inicio de sesión
        username_input.send_keys("analiticadedatosbc@sedbarranquilla.edu.co")
        password_input.send_keys("Alonso1470@")

        # Envía el formulario de inicio de sesión
        password_input.send_keys(Keys.RETURN)

    except:   
         # Encuentra los campos de entrada para el nombre de usuario y la contraseña
        username_input = driver.find_element(By.CSS_SELECTOR, "input[aria-label='Número de móvil, nombre de usuario o correo electrónico']")
        password_input = driver.find_element(By.XPATH, value = "//input[@aria-label='Contraseña']")

        # Ingresa tus credenciales de inicio de sesión
        username_input.send_keys("analiticadedatosbc@sedbarranquilla.edu.co")
        password_input.send_keys("Alonso1470@")

        # Envía el formulario de inicio de sesión
        password_input.send_keys(Keys.RETURN)
    # ENTER LINK
  
    time.sleep(8)
    driver.get(url)
    
    
    ## Scroll comments container
    pyautogui.moveTo(465, 465, duration=1)
    pyautogui.click()
    

    ## Scroll comments container
    try:
        time.sleep(1)
        pyautogui.moveTo(938, 286, duration=1)
        pyautogui.click()

        for _ in range(10): #diez intento de scroll hacia abajo 
        # pyautogui.click() 
            pyautogui.scroll(-300)  # Scroll up by 500
            time.sleep(2.5)

    
    except:
        time.sleep(1)
        # Espera a que el botón sea clickeable
        boton  = driver.find_element(By.XPATH, value = "/html/body/div[5]/div[2]/div/div/div[1]/div/div[2]/div/div/div/div/div[2]/div/div[1]/div").click()                                                                
    
        
    finally:
        pass

    
# /html/body/div[5]/div[2]/div/div/div[1]/div/div[2]/div/div/div/div/div[1]/div/div 
# "div.x1lliihq.x1n2onr6.x1roi4f4"

    # pyautogui.moveTo(1250, 463, duration=0.5) 
     
    
    
    # driver.get(url)
    # time.sleep(15)    

    comentarios = driver.find_elements(By.CSS_SELECTOR,"div.x78zum5.xdt5ytf.x1iyjqo2") #CLASE DEL CONTENEDOR DE NOMBRE DE USUARIO, COMENTARIO, HORA Y REACCIONES

    # Extraer los textos de los comentarios

    textos_comentarios = [comentario.text for comentario in comentarios]
    procesados         = [modelamiento(texto) for texto in textos_comentarios]
    flattened_data = [item for sublist in procesados for item in sublist]

    # Crear un DataFrame dividiendo cada elemento en "Usuario" y "Comentario"

    df = pd.DataFrame(flattened_data, columns=["Usuario", "Comentario", "Hora", "Reacciones"])
    df["url_instagram"] = url
    # df = pd.DataFrame([comentario.split('\n', 1) for comentario in textos_comentarios], columns=['Usuario', 'Comentario'])

    # Guardar en un archivo Excel

    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    filename = f'data/data_{medio}_{timestamp}.xlsx'
    # filename = f'data_{medio}_{timestamp}.xlsx'

    df.to_excel(filename, index=False)
    print(textos_comentarios)
    driver.quit()
    print("Excel generado con éxito 🎉")

# %%
# for url in lista_url:
#     ManagerInstagramScrapper(url,medio="medios_comunicacion")

# %% [markdown]
# ### VERSION MISMA VENTANA Y CACHE / UNICO LOGIN A LA CUENTA DE INSTRAGRAM

# %%
lista_url = [
    
    "https://www.instagram.com/p/DMyCEAkzXmb/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA==",
    "https://www.instagram.com/p/DMyB2Efx4GL/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA==",
    "https://www.instagram.com/p/DMwW8sZNn7u/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA==",
    "https://www.instagram.com/p/DMyjTSdicST/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA==",
    "https://www.instagram.com/p/DMyUEJftHuu/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA==",
    "https://www.instagram.com/p/DMyUl_rs5dK/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA=="   
    
    ]

# %%
def ManagerInstagramScrapper(urls, medio, username, password):

    # Configuración Firefox
    firefox_options = Options()
    driver = webdriver.Firefox(options=firefox_options)
    # driver.maximize_window()

    # LOGIN UNA SOLA VEZ
    driver.get("https://www.instagram.com/")
    time.sleep(3)

    try:
        username_input = driver.find_element(By.CSS_SELECTOR, "input[aria-label='Teléfono, usuario o correo electrónico']")
        password_input = driver.find_element(By.XPATH, "//input[@aria-label='Contraseña']")
    except:
        username_input = driver.find_element(By.CSS_SELECTOR, "input[aria-label='Número de móvil, nombre de usuario o correo electrónico']")
        password_input = driver.find_element(By.XPATH, "//input[@aria-label='Contraseña']")

    username_input.send_keys(username)
    password_input.send_keys(password)
    password_input.send_keys(Keys.RETURN)
    time.sleep(8)  # Esperar login

    for url in urls:
        driver.get(url)
        time.sleep(5)

        # Scroll para mostrar comentarios
        pyautogui.moveTo(465, 465, duration=1)
        pyautogui.click()
        time.sleep(1)

        try:
            pyautogui.moveTo(938, 286, duration=1)
            pyautogui.click()
            for _ in range(80):
                pyautogui.scroll(-300)
                time.sleep(2.5)
        except:
            pass

        # Extraer comentarios

        comentarios = driver.find_elements(By.CSS_SELECTOR, "div.x78zum5.xdt5ytf.x1iyjqo2") #se necesita buscar el bloque correcto, de solo usuario y comentario
        textos_comentarios = [comentario.text for comentario in comentarios]

        # Procesar comentarios con tu función modelamiento
        # procesados = [modelamiento(texto) for texto in textos_comentarios]
        # flattened_data = [item for sublist in procesados for item in sublist]

        resultado = extraer_comentarios_desde_lista(textos_comentarios)
        

        # df = pd.DataFrame(flattened_data, columns=["Usuario", "Comentario", "Hora", "Reacciones"])
        df = pd.DataFrame(resultado, columns=["Usuario", "Comentario"]).drop_duplicates(subset=["Usuario", "Comentario"])
        df["url_instagram"] = url

        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        filename = f'data/data_{medio}_{timestamp}.xlsx'
        df.to_excel(filename, index=False)

        print(f"Excel generado para {url}")
        print(textos_comentarios)


    driver.quit()
    print("Navegador cerrado y proceso finalizado.")

    return textos_comentarios

# %%
texto_scrap = ManagerInstagramScrapper(
    urls=lista_url,
    medio="instagram",
    username="analiticadedatosbc@sedbarranquilla.edu.co",
    password="Ariadna1228440@"
)
# Out:
# Excel generado para https://www.instagram.com/p/DMyCEAkzXmb/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA==
# ['biobiochile\n 6 h\nLa candidata presidencial del oficialismo, Jeannette Jara, presentó este jueves a su equipo oficial de campaña.\n\nEntre los nombres que figuran en el listado, destacan el de la exsubsecretaria general de Gobierno, Nicole Cardoch (PS), el del excandidato de la Federación Regionalista Verde Social, Jaime Mulet, y el de la secretaria general del Partido Comunista, Bárbara Figueroa.\n\nCardoch será la coordinadora territorial de la campaña, mientras que Mulet conformará su comité estratégico junto a Figueroa.\n\nEl mismo comité será integrado de igual manera por el economista, Ricardo Solari (PS); y el secretario general del Partido por la Democracia (PPD), José Toro.\n\nAsimismo, Jorge Millaquén (PS) será su jefe de gabinete, mientras que Darío Quiroga será el coordinador del comité estratégico. En tanto, Camila Miranda (FA) será la coordinadora de contenidos de la campaña.\n\nEl senador, Daniel Núñez (PC), se sumará también al equipo como coordinador de análisis electoral, y Javiera Milla será la coordinadora de producción y avanzada.', 'p_r_i_s___rs\n 6 h\nEl Dream Team del Hambre\n919 Me gusta\nResponder\nOcultar todas las respuestas\nmunoz_andres_2007\n 6 h\nEs\nResponder\njds.07\n 5 h\n😂😂😂😂😂 Buena\n3 Me gusta\nResponder\nalejonex80\n 5 h\nJajaja que buen nombre ..👏👏\n1 Me gusta\nResponder\nandyxmati21\n 4 h\nJshsjsjsjsj\n1 Me gusta\nResponder\nalonsoescobarbjj\n 3 h\nDaniel Nuñez, el que andaba robando en la ARCIS 🙌\nResponder\nsaintslaved\n 3 h\nLe dan color. No sé saben otra? El otro es el Dream team de jubilarse a los 100, trabajar 60 horas a la semana y casarse con cabras chicas.\nResponder\nalonsoescobarbjj\n 3 h\n@saintslaved ili itri bla bla…… ustedes se llenan la boca con la palabra “pueblo” pero Barbara Figueroa anda estafando a su propia Nana 😍😂\n3 Me gusta\nResponder\np_r_i_s___rs\n 3 h\n@saintslaved keaste picá Mariana 😂\nResponder\nsaintslaved\n 3 h\n@alonsoescobarbjj no escuché que estuviera equivocado scw jajajajaj suerte con los niñalovers\nResponder\nclmoralesbu\n 2 h\n@saintslaved cállate bot zurdo\nResponder\nfelipeleon5055\n 1 h\n@saintslaved pregúntale a monsalve scw\nResponder\nleoelnegroflores\n 50 min\n😂😂😂😂😂😂 wéna! Jajajajajaja\nResponder\nleonel.dario20\n 31 min\nLos Trabajolicos\nResponder\nruichenko\n 25 min\n🤣🤣🤣🤣🤣\n1 Me gusta\nResponder\ndavid_acevedo.araya\n 14 min\nMuy weno jajajajajaj\nResponder\nMostrar más respuestas\nthedanhenz\n 6 h\nMenos brillo que abrigo de gamuza\n1254 Me gusta\nResponder\nVer las 7 respuestas\nmaestro01\n 6 h\nQ lindo ver como se hunden solos\n370 Me gusta\nResponder\nVer las 2 respuestas\nfrancisco.latorreg\n 4 h\nPuras joyitas\n19 Me gusta\nResponder\nVer las 1 respuestas\ndiegodahmerr\n 6 h\nJAJAJA\n126 Me gusta\nResponder\nVer las 2 respuestas\ncapilsch89\n 6 h\nEl equipo oficial de la candidata del desempleo 😂\n102 Me gusta\nResponder\njpierre.sl\n 2 h\n🇨🇱🇨🇱🇨🇱🇨🇱 despierta…. #noalcomunismo !! 💪🏻🙌🏻\n7 Me gusta\nResponder\nalexispovea\n 6 h\nLa anti campaña activa 👌\n7 Me gusta\nResponder\nblack_mrc\n 6 h\n🤡💩 alergicos al trabajo\n668 Me gusta\nResponder\nVer las 9 respuestas\naldous.stojanovic\n 4 h\nDe: no soy comunista a gobernar con el partido comunista, preparen las ollas porque solo servirán para hacerlas sonar\n25 Me gusta\nResponder\nhernanm.z\n 6 h\nDe puro ver el cartel de Jara me asaltaron, sin comida y sin trabajo\n677 Me gusta\nResponder\nVer las 8 respuestas\nfelipeosiadacz\n 6 h\nQue miedo\n7 Me gusta\nResponder\nelisabeth.francis.hermosilla\n 6 h\nAbajo. El comunismo Chileno\n754 Me gusta\nResponder\nVer las 9 respuestas\nfrancisco_heha\n 6 h\nNunca comunismo, nunca octubrismo, jamás Jara\n1572 Me gusta\nResponder\nVer las 19 respuestas\njason.faltin\n 6 h\nJAJAJJAJAJAKAJAJAJSJAJAJAJAJAJAJAJAJAJSJAJSJAJAJAJSJSJSJSJAJAJAJAJAJAJAJAJAJAJJAJAJAJAJ\n5 Me gusta\nResponder\nnatiherediac\n 4 h\nNi en la liquidación final final final de Corona había tanto cachureo 😂😂😂\n40 Me gusta\nResponder\nVer las 3 respuestas\npierinorossi\n 6 h\nFalt ...
# Excel generado para https://www.instagram.com/p/DMyB2Efx4GL/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA==
# ['laterceracom\n 6 h\nLuego de expectativa y retrasos, Jeannette Jara presenta su equipo de campaña.\n\nLa candidata de Unidad por Chile, Jeannette Jara, anunció a su primer equipo de campaña, además de quienes integran el comité estratégico.\n\n“Quiero decirles que las prioridades de nuestro gobierno van a ser los temas de seguridad pública, los temas de crecimiento económico sustentable y con un crecimiento que llegue a la mesa de todos los chilenos y chilenas. Y en temas sociales con énfasis en educación, en salud y en vivienda”, comenzó señalando la abanderada.\n\nA pesar de finalmente revelar quienes la acompañarán en su campaña presidencial, la abanderada del Partido Comunista dejó claro que "se van a ir sumando más personas".\n\nLee más detalles a través del link en la bio 🔗', 'nico.rblanco\n 6 h\nOsvaldo Rosales es un capo👏👏👏 ayer estuve escuchándolo en la CEPAL en el seminario de aranceles. 👏👏 Tremenda inclusión al equipo 👌\n12 Me gusta\nResponder\nVer las 2 respuestas\nnicoval.944\n 6 h\nBárbara Figueroa?, la misma que no le pagaba las cotizaciones a su asesora del hogar? 😂😂\n241 Me gusta\nResponder\nVer las 5 respuestas\ntcisalb\n 4 h\n…”loh compañeroh deh lusssshaaahh , loh que estabamoh en el atentao aquella epoca “\n3 Me gusta\nResponder\nrodrigoibarra6736\n 5 h\nQue susto, Dios nos libre de el comunismo\n7 Me gusta\nResponder\ndamian_f8\n 6 h\nCon ese equipo chile no baja a la B, baja a C sin escala !!!\n42 Me gusta\nResponder\nalejandroguevara1316\n 4 h\nLA GENTE INTELIGENTE, VOTA JARA PRESIDENTE !! 🇨🇱❤️💪💪💪❤️🇨🇱\n3 Me gusta\nResponder\nVer las 4 respuestas\nveronica.col.3\n 5 h\nPa que??!! 😂😂 vaya a su casita y olvídese. Kast presidente🇨🇱🇨🇱🇨🇱🇨🇱🇨🇱🇨🇱\n2 Me gusta\nResponder\nxtian.483\n 6 h\nUf con ese equipo va a transformar Chile, en un desastre eso si 😢😂\n90 Me gusta\nResponder\njennpatito\n 6 h\nQue manera de pagar dinero a los medios de comunicación aquí está toda la plata que se robaron 😂😂\n11 Me gusta\nResponder\nstmolina2009\n 5 h\nFalto el bombo fica\n2 Me gusta\nResponder\nclaudia.ortuzar__sh\n 6 h\n😂😂😂😂 joyita de equipo, todos deseosos de un puesto en la moneda\n53 Me gusta\nResponder\nVer las 2 respuestas\nenergiasrenovablespara\n 6 h\nQue la Figueroa pague las cotizaciones previsionales de la Nana sipo, mínimo 😂\n29 Me gusta\nResponder\nfranciscoroabaeza\n 3 h\nY para que tanto show si va a ganar la derecha ??\n3 Me gusta\nResponder\nrod.alf.sch\n 6 h\nHaajajajajajajaja faltó Che copete y los Tachuelas\n72 Me gusta\nResponder\nVer las 2 respuestas\nneirarc\n 4 h\nJajajjajajjajajjajajjaja una pelicula de terror! Cm le puede llamar eso un EQUIPO 🤢\n1 Me gusta\nResponder\nmatiastl\n 6 h\n👏❤️\n2 Me gusta\nResponder\nborisrifocasanova\n 5 h\n@jeannettejararoman que bueno que no serán gobierno\n1 Me gusta\nResponder\nrobertavasquezurrutia\n 6 h\nNo al Comunismo !!!,\n42 Me gusta\nResponder\nlorecarvajalr\n 6 h\nNo gracias! Pasamos #kastpresidente\n18 Me gusta\nResponder\nVer las 1 respuestas\nrockdr190\n 4 h\nQue bueno saber que ellos serán quienes se lleven próximamente el país para la casa. Son del mismo Tren del Árbol Boric.\n1 Me gusta\nResponder\nmaricarmensalinero\n 3 h\nEquipo de vino tinto, falro Jadue y cierre de oro !!!\n2 Me gusta\nResponder\nrosaossandon_rojas\n 4 h\nTodos Comunistas.\n6 Me gusta\nResponder\nparrahectorosvaldopadilla\n 5 h\nBarbara Figueroa estrategica de no pagar la cotizaciónes de su nana\n1 Me gusta\nResponder\npata_ganso\n 6 h\nLos vendedores de humo ....más desempleo y pobreza\n38 Me gusta\nResponder\njaime.escarate\n 5 h\nQue miedo ..!!!\n1 Me gusta\nResponder\nlivinggreatplaces\n1 Me gusta\nResponder\nVer las 1 respuestas\nfrancisco_heha\n 6 h\nNunca comunismo, nunca octubrismo, jamás Jara\n63 Me gusta\nResponder\nbfb_2016\n2 Me gusta\nResponder\npamela.ravanal.3\n 5 h\nHacer énfasis en educación.... sin educación no llegamos a ninguna parte, ni derecha ni izquierda. Mal\n3 Me gusta\nResponder\nVer las 1 respuestas\nknight_scl\n 6 h\nNo pierda el tiempo señora … usted no s ...
# Excel generado para https://www.instagram.com/p/DMwW8sZNn7u/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA==
# ['theclinic_cl\n 22 h\nEl plan de la candidata presidencial de la alianza de gobierno y la Democracia Cristiana, Jeannette Jara, era presentar hoy miércoles a algunas de las figuras clave de su comando. \n\nSin embargo, esto se postergó, según aseguró la exministra, debido a la alerta roja decretada por el (Senapred) en las costas chilenas, tras el terremoto ocurrido ayer en Rusia.\n\nPese a ello, algunos nombres ya se han hecho públicos, otros, en cambio, han sostenido conversaciones con la candidata pero han acordado no integrarse al comando por ahora, sino más avanzada la campaña.\n\n Tal es el caso del alcalde de Maipú, Tomás Vodanovic, quien, según pudo conocer The Clinic, se mantuvo en contacto con la exministra del Trabajo y llegó a un acuerdo para cumplir un rol en la recta final de la campaña.\n\nSegún pudo conocer The Clinic, el edil y la candidata han sostenido varias conversaciones, en las que Tomás Vodanovic le ha manifestado a Jeannette Jara su disposición a colaborar con su campaña presidencial. Sin embargo, ambos acordaron que, por ahora, no asumirá un rol formal en el comando, para evitar desgastar su figura como alcalde, considerando que su labor al frente de una de las comunas más populosas del país no es del todo compatible con una participación activa y sostenida en una campaña nacional.\n\nPor un lado, cercanos al proceso aseguran que esta incompatibilidad se debe principalmente a razones de tiempo, dada la carga laboral que implica dirigir Maipú. A eso se suma una preocupación por las señales políticas: “No se vería bien que esté en campaña por tanto tiempo”, comentan desde su entorno.\nVodanovic, además, se encuentra en una arremetida judicial en contra de quien fue su antecesora en la alcaldía, Cathy Barriga, y su marido, el diputado Joaquín Lavín León.', 'claudio_arretx_de_celis\n 6 h\nOsea la TV hace mucho, pero que ha hecho este alcalde hasta ahora ???? Yo no he visto nada….o alguien tiene pruebas de gestión????\n2 Me gusta\nResponder\nVer las 1 respuestas\nsir._polo\n 21 h\nMe parece excelente! Estar a cargo de las mayores comuna del país es un gran responsabilidad, me parece responsable. Una coalición de centro izquierda dando ejemplo!\n3 Me gusta\nResponder\nVer las 8 respuestas\nmurzuab_\n 21 h\nVivo…, no quiere quedar sin pan ni pedazo\n28 Me gusta\nResponder\nbernarditaguida\n 12 h\nA la desesperada😂😂😂\n2 Me gusta\nResponder\nkamerica30\n 8 h\nSin goce de sueldo me imagino? Y debe tener todo ok en la comuna ? Cómo para despreocuparse del cargo? Con razón la municipalidad hacen lo que quieren y atienden como el ....\n6 Me gusta\nResponder\nlostarnau\n 6 h\nHoooi...que manera de tirar la artillería de Bost😮😮..\n1 Me gusta\nResponder\nfrangusa\n 12 h\nVodanovic cobrando 2 sueldos\n5 Me gusta\nResponder\nfranciscomirandas\n 11 h\nSobrevalorado 🙌\n2 Me gusta\nResponder\nro.albornozcapetillo\n 18 h\nSería mejor que se dedicara a trabajar en su municipio en vez de hacer campañas!\n19 Me gusta\nResponder\npatricioa7525\n 5 h\nPierden el tiempo..... Ganara y lejos KAST\n8 Me gusta\nResponder\nVer las 2 respuestas\nlagoskelly12\n 9 h\nÉste tipo, están pagando "rebien" en el PC hasta subsecretario abandonando el barco el país en el aire, el PC uno de los partidos politico más pudiente, huy toda la carne a la parrilla las arcas abiertas, me gustaría saber el gasto final de esta campaña. Si es que declaran todo\n4 Me gusta\nResponder\nkarlolavchen\n 11 h\nCuando viva en Maipu 😂😂😂\n1 Me gusta\nResponder\nelisa_porsiempre\n 10 h\n💩\n5 Me gusta\nResponder\nlysibijuli\n 7 h\nIgual este Alcalde pasa haciendo campaña mientras deja abandonada la comuna.\n2 Me gusta\nResponder\nmariaventuravaras\n 3 h\nEste quiere estar en todas... seguro gratis 🙄\n3 Me gusta\nResponder\nbescobar.scl\n 6 h\nUn pastel...\n1 Me gusta\nResponder\niren.esa1681\n 6 h\nOtro girasol,🌻\n1 Me gusta\nResponder\nctldolpz\n 4 h\nTodo terminan en el mismo mosquitero\n1 Me gusta\nResponder\nscanzu\n 5 h\nAsegura un cargo hombre por Dios 😂\n1 Me ...
# Excel generado para https://www.instagram.com/p/DMyjTSdicST/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA==
# ['adnchile\n 2 h\n| Pasado el mediodía, la candidata presidencial del oficialismo, Jeannette Jara, dio inicio a la presentación de su comando encabezado de forma transversal por todos los partidos oficialistas.\n\nSe trata de una instancia inicial, pues poco a poco se irán sumando más personeros, a la espera también de la incorporación de la Democracia Cristiana.\n\nEntre las presentaciones destacó la de Nicole Cardoch, quien renunció a su cargo de subsecretaria de la Secretaría General de Gobierno para sumarse. También se encuentra Jaime Mullet, quien sería el único candidato de las primarias que es parte del equipo.\n\nSi bien faltan personas por sumarse al comando, estos son los nombres confirmados hasta el momento:\n\nJefe de gabinete: Marcos Barraza (PC).\nCoordinador del comité estratégico: Darío Quiroga (IND).\nCoordinadora de contenidos: Camila Miranda (FA).\nCoordinadora territorial: Nicole Cardoch (PS).\nCoordinador análisis electoral: Daniel Núñez (PC).\nCoordinadora producción y avanzada: Javiera Milla (IND).\nVoceros: Eric Aedo (diputado DC) y Ricardo Lagos Webber (senador PPD).\nEquipo territorial: Jorge Millaquén (PS), Matías Toledo (alcalde de Puente Alto) y Felipe Muñoz (alcalde de Estación Central).\nEquipo estratégico: Ricardo Solari (PS), José Toro (PPD), Jaime Mulet (FRSV) y Bárbara Figueroa (PC).\nEquipo programático: Constanza Martínez (presidenta del FA) y Jaime Quintana (presidente del PPD).\nEquipo económico: Andrea Betancor, Luis Eduardo Escobar, Nicolás Bohme (PC), Osvaldo Rosales y Sebastián García.\n\n📲 Revisa más detalles en el link de la bio y ADN.CL.', 'massimo_scassi_buffa\n 2 h\nEl tren de Jaragua\n66 Me gusta\nResponder\nvidal_sub.dive\n 2 h\nEra un velorio ?\n12 Me gusta\nResponder\ngonzalezteresatapia\n 2 h\n😂😂😂👏👏\n2 Me gusta\nResponder\neliseo.pereira.12\n 1 h\nAla expectativa del Dinero Fácil...frescos\n14 Me gusta\nResponder\nab_don73\n 1 h\n✨🍄\n3 Me gusta\nResponder\nccvergaravargas\n 1 h\n🤬\n3 Me gusta\nResponder\nale.rodriguez.ale\n 1 h\n😂😂😂😂😂 DE TODOS NO SALE NI UN 1/4\n5 Me gusta\nResponder\nhrsil_\n 1 h\nNo hay duda ...todos quieren su "parte". Es la misma línea actoral, es por el "bien del país" 🤦🏻\u200d♀️\n8 Me gusta\nResponder\nsandrucafierro\n 52 min\nSe quedarán solo con las fotos, no dan para más! 😂\n2 Me gusta\nResponder\nvalenzu.cristina\n 54 min\njuntos para terminar lo que inicio el boric destruir chile\n2 Me gusta\nResponder\nmiguel.ureta.522\n 2 h\n¿era un funeral ?\n23 Me gusta\nResponder\ncarlospatricioir\n 55 min\nLa presidenta del desempleo\n2 Me gusta\nResponder\nhector_oliveros\n 1 h\nPara destruir chile eso quieren el tren del PC\n28 Me gusta\nResponder\nVer las 4 respuestas\nzamoranocarla\n 1 h\n🤢🤢🤢🤢🤢\n4 Me gusta\nResponder\nccl.280569\n 43 min\nDe todos no se hace uno\n2 Me gusta\nResponder\nbeto_lorka\n 2 h\nTremendo equipo!! #jarapresidenta #unidadporchile #unidadxchile\n2 Me gusta\nResponder\nVer las 1 respuestas\nkareempleaa\n 2 h\n❤️Jara❤️\n2 Me gusta\nResponder\nbreeders1980\n 1 h\nAL VER LA FOTO, DESAPARECIÓ MI BILLETERA😢😢😢\n8 Me gusta\nResponder\ngatocamposf\n 1 h\nEL TREN DE JARA-GUA 🧺\n22 Me gusta\nResponder\nVer las 2 respuestas\nmfloreslazo\n 2 h\nJara presidenta 😍🙌🙌🙌\n7 Me gusta\nResponder\nVer las 5 respuestas\ndavidsaezmonti\n 2 h\nTodos con la esperanza de agarrar algún puesto importante y ganar platita...\n58 Me gusta\nResponder\nVer las 1 respuestas\ncolorimetria_para_ti\n 1 h\nJara la presidenta de los narcos con amor ❤️\n5 Me gusta\nResponder\n4.7_wall\n 1 h\nSe me perdieron 20 lukas\n4 Me gusta\nResponder\nsebastiankracovich\n 1 h\nGran Circo.\n13 Me gusta\nResponder\nantiprogrectm\n 1 h\nSúbase a la Jaraneta del desempleo 😂 con amor ❤️❤️\n21 Me gusta\nResponder\nVer las 2 respuestas\nrubensandoval680\n 1 h\nWuajajajjajajajajajajjaja........ Kast presidente\n10 Me gusta\nResponder\nVer las 2 respuestas\nelieli011\n 48 min\nNo tienes mi voto!\n2 Me gusta\nResponder\nkarisilva27\n 2 h\n🤮🤮🤮🤮\n6 Me gusta\nResponder\nchrisking_a10\n 1 h\nNo vot ...
# Excel generado para https://www.instagram.com/p/DMyUEJftHuu/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA==
# ['cooperativa\n 4 h\n📄En el emblemático barrio París-Londres, en Santiago Centro, la candidata presidencial del oficialismo, Jeannette Jara (Partido Comunista), presentó este jueves a su nuevo comando de campaña, que la acompañará en la carrera hacia las elecciones de noviembre 🗳. #jeannettejara #jara #comando #elecciones #chile', 'felimoreiraflores\n 2 h\nLas mansas joyas!!!! 🔥🔥🔥\n5 Me gusta\nResponder\nuron.eriosyce\n 2 h\n#JaraPresidenta❤️ 👏👏👏\n1 Me gusta\nResponder\nrg0910\n 4 h\nCada uno con su librito de marx debajo de la iPad 🤣🤣\n43 Me gusta\nResponder\nVer las 7 respuestas\npavelnoir_\n 4 h\nEl comando de la pobreza 😂\n9 Me gusta\nResponder\nbrunaaguileragonzalez\n 4 h\nJeannette Jara presidenta 💖\n43 Me gusta\nResponder\nVer las 4 respuestas\nstebanrussh\n182 Me gusta\nResponder\nVer las 5 respuestas\npame_5017\n 2 h\n#jeannettejarapresidenta ❤️\n1 Me gusta\nResponder\nVer traducción\nspavez30\n 1 h\nEl tren de MIMBRE 😂\n4 Me gusta\nResponder\nVer las 3 respuestas\nmaitita3981\n 4 h\nLOS MIMOS ENS DE SIEMPRE.!!! TODOS NUEVAMENTE A LLENAR LOS. BOLSILLOS DE DINERO DEL ESTADO\n39 Me gusta\nResponder\nVer las 4 respuestas\nnachovd92\n 1 h\nCallampa\n1 Me gusta\nResponder\npablovceth\n 2 h\nEstán mostrando la lista del cartel ??...\n2 Me gusta\nResponder\nelvis_garcia2026\n 2 h\nTodo Huele a 12 de octubre con la Checopeta jajjajajaja\n4 Me gusta\nResponder\nVer las 1 respuestas\nvictor.andres87\n 3 h\nComunista de mall\n10 Me gusta\nResponder\nferconketchup\n 3 h\nKast lleva como 16 años de candidato, ni comando tiene 🤣\n73 Me gusta\nResponder\nVer las 7 respuestas\nniiicoar\n 3 h\nEl comando de la cesantía y pobreza\n33 Me gusta\nResponder\ngabrielramosmoiny\n 4 h\nTremendo equipo, experiencia, renovación liderazgo, todo junto a una candidata muy cercana y dos carreras universitarias\n95 Me gusta\nResponder\nVer las 27 respuestas\njosehidalgoarriagada\n 3 h\nEl comando del hambre 👌👌\n62 Me gusta\nResponder\nVer las 2 respuestas\nvicentetorresgh\n 1 h\nChile ,el único país del mundo que apoya a una comunista, seremos muy.....\n1 Me gusta\nResponder\nmigxel_gal\n 3 h\nComunistas presentado un grupo económico 🤣🤣🤣🤣\n45 Me gusta\nResponder\nVer las 2 respuestas\nalexosorio316\n 4 h\nCuántos de estos saldrán en las noticias en el futuro por algún asunto de corrupción.\n212 Me gusta\nResponder\nVer las 26 respuestas\nfelipin_81\n 4 h\nKAST PRESIDENTE 🇨🇱🇨🇱🇨🇱\n89 Me gusta\nResponder\nVer las 2 respuestas\ngaudi_gym\n 2 h\nNo podia ser peor 🔥🔥🔥 mas hacen mas la cagan 😂😂😂😂 . Chile ya se decidio por cualquiera menos jara 🇨🇱🇨🇱🇨🇱\n6 Me gusta\nResponder\njobelirodriguez\n 4 h\ncon ustedes : EL TREN DE JARAGUA!!!!\n495 Me gusta\nResponder\nVer las 31 respuestas\nclaudioxelmundo\n 56 min\nChimbarongo team.\n2 Me gusta\nResponder\nVer traducción\nlsflp3.cg\n 4 h\nUna generación dorada 😂😂😂\n123 Me gusta\nResponder\nVer las 15 respuestas\n_rafiikii\n 2 h\nSon como los créditos de una película de terror\n2 Me gusta\nResponder\npibecoke\n 3 h\nWaaaajajajjajajaua 😂😂😂 el circo zurdo 😂😂 Q manera de hacernos reír 😂😂\n18 Me gusta\nResponder\nVer las 1 respuestas\nniu_gonza\n 4 h\nFigueroa Po jajajsjaj😂😂😂\n41 Me gusta\nResponder\nVer las 2 respuestas\ntraspapelaooo\n 4 h\nPuros Empresarios y Profesionales, mientras que el equipo de Kast: puros militares y el economista que creo y formuló toda la Colusión de los Pollos y el Confort\n53 Me gusta\nResponder\nVer las 7 respuestas\nmatiastl\n 4 h\nY Kast tiene al de la colusión de los pollos 😂\n138 Me gusta\nResponder\nVer las 4 respuestas\nvopazor113\n 4 h\nPuros comunistas\n112 Me gusta\nResponder\nVer las 11 respuestas\nmarialuisaariasmunoz\n 4 h\nJARA PRESIDENTA de CHILE 🫰🏻\n49 Me gusta\nResponder\nVer las 5 respuestas\nvitoriocabrera\n 4 h\nLa candidata del Pueblo , la de verdad, la de mimbre , la de Maduro , la de Fidel , la de Allende ..la ex comunista\n52 Me gusta\nResponder\nVer las 10 respuestas\nroydcapella\n 1 h\nGareca presentaba mejor equipo 😂\n1 Me gusta\nResponder\nhunk_u.s.s48\n 2 h\nHas ...
# Excel generado para https://www.instagram.com/p/DMyUl_rs5dK/?utm_source=ig_web_copy_link&igsh=MzRlODBiNWFlZA==
# ['el_mostrador\n 4 h\n📍Con un acto en su comando en Londres 76, la abanderada del oficialismo presentó a su núcleo estratégico, compuesto por figuras del mundo sindical, académico, parlamentario y municipal. Se trató de una revelación “parcial”. Jara precisó que los voceros serán dados a conocer la próxima semana.\n\n🧐El objetivo, según recalcó Jara, es proyectar una imagen de gobernabilidad y amplitud política. En ese marco, la incorporación de figuras del PS, PPD, FA, FRVS, PC y la DC busca mostrar unidad tanto dentro del oficialismo como más allá de sus fronteras.\n\n📣El lanzamiento, realizado en la sede de su comando en Londres 76 —la misma que usó Carolina Tohá en la primaria del oficialismo—, congregó a los principales rostros que integrarán su estructura de campaña. Pese a la amenaza de lluvia y tras una demora de más de una hora respecto a la hora prevista, Jara —que previamente participó en un nuevo debate presidencial en la Sofofa— inició la actividad a las 13:20 con bandera chilena proyectada, himno nacional y carteles con la tipografía ya instalada de su campaña.\n\n🗣️“Quiero aclarar que esta es una primera incorporación, se van a ir sumando más personas”, partió señalando la abanderada oficialista, agregando que los voceros serán presentados la próxima semana. Esto último, luego de que ayer se hablara de la incorporación del senador Ricardo Lagos Weber (PPD) y del diputado Eric Aedo (DC) en esa área.\n\nSiga leyendo en el link de la bio y en elmostrador.cl 📱', 'angelmergonzalez\n 3 h\nNunca comunismo..quiere ser más pobre?\n21 Me gusta\nResponder\nVer las 2 respuestas\ngustavo.munoz383\n 2 h\n😂😂😂😂😂\n1 Me gusta\nResponder\ncybertron1974\n1 Me gusta\nResponder\nnico_said.n\n1 Me gusta\nResponder\nuron.eriosyce\n 4 h\n#JaraPresidenta ❤️\n1 Me gusta\nResponder\nVer las 1 respuestas\nkaren_bondi2\n 4 h\nDonde es será la primera función ?\n4 Me gusta\nResponder\nrenatomery_\n 3 h\nPuras joyas\n2 Me gusta\nResponder\nmanuelmartinez.quintana\n2 Me gusta\nResponder\nemeteriomatus\n 4 h\nSiii, la primera línea en una sola foto\n8 Me gusta\nResponder\nrobertoaguirre180618\n19 Me gusta\nResponder\nrodrigo.guti\n 2 h\nMinistra del Desempleo y su Equipo\n5 Me gusta\nResponder\nVer las 1 respuestas\nrodrigourtubiag\n 2 h\nUnidad ???? Nunca el Comunista sera unido a un NO Comunista\n1 Me gusta\nResponder\nmarina.olguin.l\n 3 h\n🎪🎪🎪🎪🎪\n2 Me gusta\nResponder\nmdominguezb\n 3 h\nJajaajaj falta la tía Pikachu y estamos 😂\n7 Me gusta\nResponder\ngonchalo76\n 2 h\nJara presenta su equipo de "los juegos del hambre" jajaja 😂\n3 Me gusta\nResponder\njomd__\n 2 h\n😂😂😂😂😂😂😂😂😂\n1 Me gusta\nResponder\nrenato_brito69\n 3 h\nDa lo mismo quien esté no saldrá presidenta\n3 Me gusta\nResponder\ncarlosalejllanos\n 3 h\nUnidad y un buen despliegue en terreno , de Arica a Pta Arenas.💪🏼\n4 Me gusta\nResponder\nsebastiankracovich\n 4 h\nA esa se llama Núcleo Estratégico?...\n2 Me gusta\nResponder\nolavesoledad\n 3 h\nComunismo = pobreza\n12 Me gusta\nResponder\nVer las 1 respuestas\nbrunaaguileragonzalez\n 4 h\nJeannette Jara presidenta.\n17 Me gusta\nResponder\nVer las 1 respuestas\npoluxcarnabalon\n 4 h\nAlejándose de la centro izquierda.... No le va a convenir para nada\n5 Me gusta\nResponder\ncarcamo613\n 3 h\nFalta la calila y la mojojo😂\n4 Me gusta\nResponder\nsiar_kin\n 4 h\nCon este equipo, pfff\n9 Me gusta\nResponder\ncarcuraa\n 3 h\nPuros iluminados\n4 Me gusta\nResponder\npibecoke\n 3 h\nWaaajajajajaja 😂😂😂😂Q manera de reír con estos zurdos 😂😂😂\n3 Me gusta\nResponder\nsolange.moralesmarin\n 1 h\n🤮🤮🤮🤮🤮🤮🤮🤮🐀🐀🐀🐀🐀🐀🐀🐀🐀🐷🐷🐷🐷🐷🐷🐷🐷👹👹👹👹👹👹👹👹👹🐉🐉🐉🐉🐉🐉💀💀💀💀💀💀💀💀💀💀💀💀💀💀👹👹👹👹\n1 Me gusta\nResponder\ncarlosgallarces\n 4 h\n🐀🐀🐀🐀🤡🤡🤡😂😂😂\n2 Me gusta\nResponder\ndiegoheinkel\n 3 h\nVi la lista, me rugieron las tripas y se me perdieron 5 lucas\n5 Me gusta\nResponder\nVer las 4 respuestas\nbjvs1978\n 4 h\nJeannette Jara presidenta 🇨🇱 por un chile sin la ultraderecha pinochetista y cavernaria.\n22 Me gusta\nResponder\nVer las 16 respuestas\nfabian.dodero\n 3 h\nPreparados pa ...
# Navegador cerrado y proceso finalizado.

# %%
# LIMPIEZA DATAFRAME Y CONSOLIDADO DIARIO
# ruta_directorio = "/data/data final"
# ruta_archivo = os.path.join(ruta_directorio, "archivo_unido.xlsx")

carpeta = '/Users/admin/Documents/Proyectos Programacion/Vault - Github/2. Proyectos/1. Interpreta Chile/01 Instagram - Proyectos/instagram scraper/data'

archivos = [f for f in os.listdir(carpeta) if f.endswith((".xlsx",".xls"))]
dataframes = []

for archivo in archivos:
    ruta_completa = os.path.join(carpeta,archivo)
    df = pd.read_excel(ruta_completa)
    dataframes.append(df)

df_final = pd.concat(dataframes,ignore_index=True)

# %%
df_final.to_excel('310725_data_instragram_interpreta.xlsx',index=False)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
